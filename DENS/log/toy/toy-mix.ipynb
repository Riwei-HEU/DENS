# %%
# %load main.py
import os
import random

import torch
import numpy as np

from time import time
from tqdm import tqdm
from copy import deepcopy
import logging
from prettytable import PrettyTable

from utils.parser import parse_args
from utils.data_loader import load_data
from utils.evaluate import test
from utils.helper import early_stopping

n_users = 0
n_items = 0


def get_feed_dict(train_entity_pairs, train_pos_set, start, end, n_negs=1):

    def sampling(user_item, train_set, n):
        neg_items = []
        for user, _ in user_item.cpu().numpy():
            user = int(user)
            negitems = []
            for i in range(n):  # sample n times
                while True:
                    negitem = random.choice(range(n_items))
                    if negitem not in train_set[user]:
                        break
                negitems.append(negitem)
            neg_items.append(negitems)
        return neg_items

    feed_dict = {}
    entity_pairs = train_entity_pairs[start:end]
    feed_dict['users'] = entity_pairs[:, 0]
    feed_dict['pos_items'] = entity_pairs[:, 1]
    feed_dict['neg_items'] = torch.LongTensor(sampling(entity_pairs,
                                                       train_pos_set,
                                                       n_negs*K)).to(device)
    return feed_dict


if __name__ == '__main__':
    """fix the random seed"""
    seed = 2020
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    """read args"""
    global args, device
    args = parse_args()
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)
    device = torch.device("cuda:0") if args.cuda else torch.device("cpu")

    """build dataset"""
    train_cf, user_dict, n_params, norm_mat = load_data(args)
    train_cf_size = len(train_cf)
    train_cf = torch.LongTensor(np.array([[cf[0], cf[1]] for cf in train_cf], np.int32))

    n_users = n_params['n_users']
    n_items = n_params['n_items']
    n_negs = args.n_negs
    K = args.K

    """define model"""
    from modules.LightGCN import LightGCN
    if args.gnn == 'lightgcn':
        model = LightGCN(n_params, args, norm_mat).to(device)

    """define optimizer"""
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    cur_best_pre_0 = 0
    stopping_step = 0
    should_stop = False

    print("start training ...")
    for epoch in range(args.epoch):
        # shuffle training data
        train_cf_ = train_cf
        index = np.arange(len(train_cf_))
        np.random.shuffle(index)
        train_cf_ = train_cf_[index].to(device)

        """training"""
        model.train()
        loss, s = 0, 0
        hits = 0
        train_s_t = time()
        while s + args.batch_size <= len(train_cf):
            batch = get_feed_dict(train_cf_,
                                  user_dict['train_user_set'],
                                  s, s + args.batch_size,
                                  n_negs)

            batch_loss, _, _ = model(epoch, batch)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            loss += batch_loss
            s += args.batch_size

        train_e_t = time()

        if epoch % 5 == 0:
            """testing"""

            train_res = PrettyTable()
            train_res.field_names = ["Epoch", "training time(s)", "tesing time(s)", "Loss", "recall", "ndcg", "precision", "hit_ratio"]

            model.eval()
            test_s_t = time()
            test_ret = test(model, user_dict, n_params, mode='test')
            test_e_t = time()
            train_res.add_row(
                [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), test_ret['recall'], test_ret['ndcg'],
                 test_ret['precision'], test_ret['hit_ratio']])

            if user_dict['valid_user_set'] is None:
                valid_ret = test_ret
            else:
                test_s_t = time()
                valid_ret = test(model, user_dict, n_params, mode='valid')
                test_e_t = time()
                train_res.add_row(
                    [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), valid_ret['recall'], valid_ret['ndcg'],
                     valid_ret['precision'], valid_ret['hit_ratio']])
            print(train_res)

            # *********************************************************
            # early stopping when cur_best_pre_0 is decreasing for 10 successive steps.
            cur_best_pre_0, stopping_step, should_stop = early_stopping(valid_ret['recall'][0], cur_best_pre_0,
                                                                        stopping_step, expected_order='acc',
                                                                        flag_step=10)
            if should_stop:
                break

            """save weight"""
            if valid_ret['recall'][0] == cur_best_pre_0 and args.save:
                torch.save(model.state_dict(), args.out_dir + 'model_' + '.ckpt')
        else:
            # logging.info('training loss at epoch %d: %f' % (epoch, loss.item()))
            print('using time %.4fs, training loss at epoch %d: %.4f' % (train_e_t - train_s_t, epoch, loss.item()))

    print('early stopping at %d, recall@20:%.4f' % (epoch, cur_best_pre_0))
# Out:
# reading train and test user-item set ...
# building the adj mat ...
# {'n_users': 4626, 'n_items': 10083}
# loading over ...
# start training ...
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   0   | 1.941781997680664 | 2.4404938220977783 | 14.554248809814453 | [0.01961015] | [0.01035314] | [0.00197698] | [0.03103103] |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 1.8333s, training loss at epoch 1: 14.5440
# using time 1.9000s, training loss at epoch 2: 14.5162
# using time 1.9469s, training loss at epoch 3: 14.4564
# using time 1.8672s, training loss at epoch 4: 14.3554
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# |   5   | 1.8391151428222656 | 2.3955724239349365 | 14.215155601501465 | [0.03933798] | [0.02120357] | [0.0043043] | [0.06956957] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# using time 1.7048s, training loss at epoch 6: 14.0360
# using time 1.5055s, training loss at epoch 7: 13.8364
# using time 1.7389s, training loss at epoch 8: 13.6271
# using time 1.5895s, training loss at epoch 9: 13.3909
# +-------+--------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# |   10  | 1.6347565650939941 | 2.400132894515991 | 13.184828758239746 | [0.0424099] | [0.02241067] | [0.00464214] | [0.07607608] |
# +-------+--------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 1.6027s, training loss at epoch 11: 12.9526
# using time 1.6366s, training loss at epoch 12: 12.7425
# using time 1.7719s, training loss at epoch 13: 12.5523
# using time 1.5958s, training loss at epoch 14: 12.3643
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   15  | 1.6493113040924072 | 2.421541690826416 | 12.164953231811523 | [0.04407159] | [0.02371397] | [0.00479229] | [0.07857858] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 1.4783s, training loss at epoch 16: 11.9298
# using time 1.6055s, training loss at epoch 17: 11.7735
# using time 1.4411s, training loss at epoch 18: 11.5980
# using time 1.5923s, training loss at epoch 19: 11.3975
# +-------+--------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# |   20  | 1.4541008472442627 | 2.464614152908325 | 11.209016799926758 | [0.04521569] | [0.02393278] | [0.0049049] | [0.08108108] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# using time 1.5793s, training loss at epoch 21: 11.0302
# using time 1.5712s, training loss at epoch 22: 10.8141
# using time 1.5303s, training loss at epoch 23: 10.6287
# using time 1.4129s, training loss at epoch 24: 10.4287
# +-------+--------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |  tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# |   25  | 1.5412836074829102 | 2.46197247505188 | 10.237041473388672 | [0.04694718] | [0.02461263] | [0.00501752] | [0.08308308] |
# +-------+--------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 1.8014s, training loss at epoch 26: 10.1138
# using time 1.9652s, training loss at epoch 27: 9.8893
# using time 1.9087s, training loss at epoch 28: 9.7379
# using time 1.9728s, training loss at epoch 29: 9.5795
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# |   30  | 1.9378912448883057 | 2.3573808670043945 | 9.397250175476074 | [0.04649792] | [0.0245062] | [0.00499249] | [0.08283283] |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# using time 1.9399s, training loss at epoch 31: 9.2430
# using time 2.0112s, training loss at epoch 32: 9.0693
# using time 1.8741s, training loss at epoch 33: 8.9169
# using time 1.7043s, training loss at epoch 34: 8.7586
# +-------+--------------------+-------------------+------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |       Loss       |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+-------------------+------------------+--------------+--------------+-------------+--------------+
# |   35  | 1.7792901992797852 | 2.353262424468994 | 8.55808162689209 | [0.04577776] | [0.02441288] | [0.0049049] | [0.08158158] |
# +-------+--------------------+-------------------+------------------+--------------+--------------+-------------+--------------+
# using time 1.6973s, training loss at epoch 36: 8.4287
# using time 1.7689s, training loss at epoch 37: 8.3365
# using time 1.6815s, training loss at epoch 38: 8.1711
# using time 1.6915s, training loss at epoch 39: 7.9626
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   40  | 1.7208173274993896 | 2.4504828453063965 | 7.899941921234131 | [0.04700782] | [0.02472794] | [0.00496747] | [0.08258258] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.5452s, training loss at epoch 41: 7.7716
# using time 1.9422s, training loss at epoch 42: 7.6356
# using time 1.8507s, training loss at epoch 43: 7.5303
# using time 1.8588s, training loss at epoch 44: 7.4114
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   45  | 1.8692121505737305 | 2.476656913757324 | 7.266012191772461 | [0.04707734] | [0.02465241] | [0.00492993] | [0.08208208] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.8003s, training loss at epoch 46: 7.1500
# using time 1.8864s, training loss at epoch 47: 7.0030
# using time 1.8822s, training loss at epoch 48: 6.9468
# using time 1.9122s, training loss at epoch 49: 6.8076
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# |   50  | 1.8547382354736328 | 2.4568021297454834 | 6.697421550750732 | [0.0466248] | [0.02430608] | [0.00489239] | [0.08108108] |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# using time 1.9665s, training loss at epoch 51: 6.6206
# using time 1.9149s, training loss at epoch 52: 6.5221
# using time 1.8434s, training loss at epoch 53: 6.3977
# using time 1.8824s, training loss at epoch 54: 6.3090
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   55  | 1.9160857200622559 | 2.4370036125183105 | 6.2313642501831055 | [0.04633669] | [0.02444351] | [0.00484234] | [0.08033033] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 1.8621s, training loss at epoch 56: 6.1429
# using time 2.0109s, training loss at epoch 57: 6.0666
# using time 1.8676s, training loss at epoch 58: 5.9594
# using time 1.8384s, training loss at epoch 59: 5.9376
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   60  | 1.8779504299163818 | 2.466806173324585 | 5.824098587036133 | [0.04657681] | [0.02461252] | [0.00485485] | [0.08033033] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.9097s, training loss at epoch 61: 5.7353
# using time 1.9326s, training loss at epoch 62: 5.6773
# using time 1.9093s, training loss at epoch 63: 5.5993
# using time 1.8705s, training loss at epoch 64: 5.5563
# +-------+--------------------+--------------------+-------------------+--------------+-------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg    |  precision  |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+-------------+--------------+
# |   65  | 1.8196806907653809 | 2.4573540687561035 | 5.415595531463623 | [0.04684772] | [0.0245238] | [0.0049049] | [0.08083083] |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+-------------+--------------+
# using time 1.7969s, training loss at epoch 66: 5.3731
# using time 1.8537s, training loss at epoch 67: 5.3039
# using time 1.8557s, training loss at epoch 68: 5.2174
# using time 1.8653s, training loss at epoch 69: 5.1845
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   70  | 1.7834351062774658 | 2.435141086578369 | 5.047608852386475 | [0.04675772] | [0.02466326] | [0.00492993] | [0.08108108] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.8315s, training loss at epoch 71: 5.0596
# using time 1.8458s, training loss at epoch 72: 4.9473
# using time 1.8099s, training loss at epoch 73: 4.9014
# using time 1.8876s, training loss at epoch 74: 4.8223
# +-------+-------------------+-------------------+-------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+-------------------+-------------------+-------------------+--------------+--------------+-------------+--------------+
# |   75  | 1.849705696105957 | 2.469917058944702 | 4.800631046295166 | [0.04647827] | [0.02446718] | [0.0049049] | [0.08108108] |
# +-------+-------------------+-------------------+-------------------+--------------+--------------+-------------+--------------+
# using time 1.9283s, training loss at epoch 76: 4.7702
# using time 1.9044s, training loss at epoch 77: 4.7016
# using time 1.9032s, training loss at epoch 78: 4.6221
# using time 1.8942s, training loss at epoch 79: 4.5750
# +-------+--------------------+--------------------+------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |       Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+------------------+-------------+--------------+--------------+--------------+
# |   80  | 1.8620784282684326 | 2.4581425189971924 | 4.51285982131958 | [0.0461738] | [0.02408195] | [0.00489239] | [0.08033033] |
# +-------+--------------------+--------------------+------------------+-------------+--------------+--------------+--------------+
# using time 1.9099s, training loss at epoch 81: 4.4525
# using time 1.9784s, training loss at epoch 82: 4.4463
# using time 1.7976s, training loss at epoch 83: 4.3589
# using time 1.8826s, training loss at epoch 84: 4.3375
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   85  | 1.9010837078094482 | 2.5098018646240234 | 4.308823108673096 | [0.04682862] | [0.02426742] | [0.00492993] | [0.08083083] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.9576s, training loss at epoch 86: 4.2305
# using time 1.8680s, training loss at epoch 87: 4.2208
# using time 1.8312s, training loss at epoch 88: 4.1371
# using time 1.8866s, training loss at epoch 89: 4.0882
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   90  | 1.9174749851226807 | 2.4659924507141113 | 4.054162979125977 | [0.04604626] | [0.02417227] | [0.00479229] | [0.07882883] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.8051s, training loss at epoch 91: 3.9833
# using time 1.8607s, training loss at epoch 92: 3.9618
# using time 1.8134s, training loss at epoch 93: 3.9656
# using time 1.7550s, training loss at epoch 94: 3.9131
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   95  | 1.7913284301757812 | 2.373364210128784 | 3.895970106124878 | [0.04613385] | [0.02401093] | [0.00477978] | [0.07907908] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# Early stopping is trigger at step: 10 log:0.04613384971572112
# early stopping at 95, recall@20:0.0471
