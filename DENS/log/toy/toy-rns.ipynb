# %%
# %load main.py
import os
import random

import torch
import numpy as np

from time import time
from tqdm import tqdm
from copy import deepcopy
import logging
from prettytable import PrettyTable

from utils.parser import parse_args
from utils.data_loader import load_data
from utils.evaluate import test
from utils.helper import early_stopping

n_users = 0
n_items = 0


def get_feed_dict(train_entity_pairs, train_pos_set, start, end, n_negs=1):

    def sampling(user_item, train_set, n):
        neg_items = []
        for user, _ in user_item.cpu().numpy():
            user = int(user)
            negitems = []
            for i in range(n):  # sample n times
                while True:
                    negitem = random.choice(range(n_items))
                    if negitem not in train_set[user]:
                        break
                negitems.append(negitem)
            neg_items.append(negitems)
        return neg_items

    feed_dict = {}
    entity_pairs = train_entity_pairs[start:end]
    feed_dict['users'] = entity_pairs[:, 0]
    feed_dict['pos_items'] = entity_pairs[:, 1]
    feed_dict['neg_items'] = torch.LongTensor(sampling(entity_pairs,
                                                       train_pos_set,
                                                       n_negs*K)).to(device)
    return feed_dict


if __name__ == '__main__':
    """fix the random seed"""
    seed = 2020
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    """read args"""
    global args, device
    args = parse_args()
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)
    device = torch.device("cuda:0") if args.cuda else torch.device("cpu")

    """build dataset"""
    train_cf, user_dict, n_params, norm_mat = load_data(args)
    train_cf_size = len(train_cf)
    train_cf = torch.LongTensor(np.array([[cf[0], cf[1]] for cf in train_cf], np.int32))

    n_users = n_params['n_users']
    n_items = n_params['n_items']
    n_negs = args.n_negs
    K = args.K

    """define model"""
    from modules.LightGCN import LightGCN
    if args.gnn == 'lightgcn':
        model = LightGCN(n_params, args, norm_mat).to(device)

    """define optimizer"""
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    cur_best_pre_0 = 0
    stopping_step = 0
    should_stop = False

    print("start training ...")
    for epoch in range(args.epoch):
        # shuffle training data
        train_cf_ = train_cf
        index = np.arange(len(train_cf_))
        np.random.shuffle(index)
        train_cf_ = train_cf_[index].to(device)

        """training"""
        model.train()
        loss, s = 0, 0
        hits = 0
        train_s_t = time()
        while s + args.batch_size <= len(train_cf):
            batch = get_feed_dict(train_cf_,
                                  user_dict['train_user_set'],
                                  s, s + args.batch_size,
                                  n_negs)

            batch_loss, _, _ = model(epoch, batch)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            loss += batch_loss
            s += args.batch_size

        train_e_t = time()

        if epoch % 5 == 0:
            """testing"""

            train_res = PrettyTable()
            train_res.field_names = ["Epoch", "training time(s)", "tesing time(s)", "Loss", "recall", "ndcg", "precision", "hit_ratio"]

            model.eval()
            test_s_t = time()
            test_ret = test(model, user_dict, n_params, mode='test')
            test_e_t = time()
            train_res.add_row(
                [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), test_ret['recall'], test_ret['ndcg'],
                 test_ret['precision'], test_ret['hit_ratio']])

            if user_dict['valid_user_set'] is None:
                valid_ret = test_ret
            else:
                test_s_t = time()
                valid_ret = test(model, user_dict, n_params, mode='valid')
                test_e_t = time()
                train_res.add_row(
                    [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), valid_ret['recall'], valid_ret['ndcg'],
                     valid_ret['precision'], valid_ret['hit_ratio']])
            print(train_res)

            # *********************************************************
            # early stopping when cur_best_pre_0 is decreasing for 10 successive steps.
            cur_best_pre_0, stopping_step, should_stop = early_stopping(valid_ret['recall'][0], cur_best_pre_0,
                                                                        stopping_step, expected_order='acc',
                                                                        flag_step=10)
            if should_stop:
                break

            """save weight"""
            if valid_ret['recall'][0] == cur_best_pre_0 and args.save:
                torch.save(model.state_dict(), args.out_dir + 'model_' + '.ckpt')
        else:
            # logging.info('training loss at epoch %d: %f' % (epoch, loss.item()))
            print('using time %.4fs, training loss at epoch %d: %.4f' % (train_e_t - train_s_t, epoch, loss.item()))

    print('early stopping at %d, recall@20:%.4f' % (epoch, cur_best_pre_0))
# Out:
# reading train and test user-item set ...
# building the adj mat ...
# {'n_users': 4626, 'n_items': 10083}
# loading over ...
# start training ...
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   0   | 0.47034788131713867 | 1.8267369270324707 | 14.540289878845215 | [0.02154832] | [0.01160856] | [0.00223974] | [0.03528529] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4846s, training loss at epoch 1: 14.4346
# using time 0.4728s, training loss at epoch 2: 14.0251
# using time 0.5142s, training loss at epoch 3: 13.1932
# using time 0.5081s, training loss at epoch 4: 12.1101
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   5   | 0.48691558837890625 | 1.7962212562561035 | 11.061481475830078 | [0.02576392] | [0.01333455] | [0.00276527] | [0.04404404] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4698s, training loss at epoch 6: 10.1460
# using time 0.5325s, training loss at epoch 7: 9.4681
# using time 0.5050s, training loss at epoch 8: 8.9231
# using time 0.4922s, training loss at epoch 9: 8.4644
# +-------+---------------------+-------------------+------------------+-------------+--------------+-------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |       Loss       |    recall   |     ndcg     |  precision  |  hit_ratio   |
# +-------+---------------------+-------------------+------------------+-------------+--------------+-------------+--------------+
# |   10  | 0.45936059951782227 | 1.788576364517212 | 8.03012752532959 | [0.0286627] | [0.01499545] | [0.0031031] | [0.05105105] |
# +-------+---------------------+-------------------+------------------+-------------+--------------+-------------+--------------+
# using time 0.4734s, training loss at epoch 11: 7.6923
# using time 0.4978s, training loss at epoch 12: 7.4402
# using time 0.4632s, training loss at epoch 13: 7.0533
# using time 0.4739s, training loss at epoch 14: 6.7009
# +-------+---------------------+-------------------+-------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+-------------+--------------+--------------+--------------+
# |   15  | 0.48873305320739746 | 1.921203374862671 | 6.470574855804443 | [0.0307387] | [0.01685362] | [0.00347848] | [0.05705706] |
# +-------+---------------------+-------------------+-------------------+-------------+--------------+--------------+--------------+
# using time 0.4747s, training loss at epoch 16: 6.2275
# using time 0.4929s, training loss at epoch 17: 5.9663
# using time 0.4859s, training loss at epoch 18: 5.7210
# using time 0.4837s, training loss at epoch 19: 5.4898
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   20  | 0.4847276210784912 | 1.796506643295288 | 5.360439300537109 | [0.03306902] | [0.01804106] | [0.00369119] | [0.06231231] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.4612s, training loss at epoch 21: 5.1172
# using time 0.4951s, training loss at epoch 22: 4.9631
# using time 0.4762s, training loss at epoch 23: 4.7224
# using time 0.4694s, training loss at epoch 24: 4.6747
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   25  | 0.47857117652893066 | 1.7903392314910889 | 4.468512535095215 | [0.03570529] | [0.01905274] | [0.00406657] | [0.06906907] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.4818s, training loss at epoch 26: 4.3623
# using time 0.4641s, training loss at epoch 27: 4.1696
# using time 0.4849s, training loss at epoch 28: 4.0459
# using time 0.5242s, training loss at epoch 29: 3.9497
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |   30  | 0.4655599594116211 | 1.8175735473632812 | 3.8185880184173584 | [0.0375284] | [0.01978971] | [0.00421672] | [0.07182182] |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.4569s, training loss at epoch 31: 3.7129
# using time 0.4970s, training loss at epoch 32: 3.6328
# using time 0.4800s, training loss at epoch 33: 3.5478
# using time 0.4868s, training loss at epoch 34: 3.4051
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# |   35  | 0.4819777011871338 | 1.7802844047546387 | 3.344244956970215 | [0.0377466] | [0.02003642] | [0.00424174] | [0.07207207] |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# using time 0.4694s, training loss at epoch 36: 3.2801
# using time 0.4759s, training loss at epoch 37: 3.1276
# using time 0.4720s, training loss at epoch 38: 3.1488
# using time 0.4850s, training loss at epoch 39: 3.0510
# +-------+--------------------+-------------------+--------------------+------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |   recall   |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+------------+--------------+-------------+--------------+
# |   40  | 0.5138511657714844 | 1.796872615814209 | 2.9362497329711914 | [0.038519] | [0.02027095] | [0.0043043] | [0.07332332] |
# +-------+--------------------+-------------------+--------------------+------------+--------------+-------------+--------------+
# using time 0.4695s, training loss at epoch 41: 2.8699
# using time 0.4871s, training loss at epoch 42: 2.8842
# using time 0.4817s, training loss at epoch 43: 2.8069
# using time 0.4624s, training loss at epoch 44: 2.7396
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   45  | 0.4665219783782959 | 1.7772347927093506 | 2.6322333812713623 | [0.03894145] | [0.02047652] | [0.00436687] | [0.07432432] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4893s, training loss at epoch 46: 2.6081
# using time 0.4725s, training loss at epoch 47: 2.5378
# using time 0.4928s, training loss at epoch 48: 2.5520
# using time 0.4796s, training loss at epoch 49: 2.4378
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   50  | 0.49297547340393066 | 1.8141717910766602 | 2.435375928878784 | [0.04021117] | [0.02096495] | [0.00449199] | [0.07657658] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.4739s, training loss at epoch 51: 2.3748
# using time 0.4533s, training loss at epoch 52: 2.2830
# using time 0.4648s, training loss at epoch 53: 2.2951
# using time 0.5354s, training loss at epoch 54: 2.2379
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   55  | 0.4846372604370117 | 1.7921371459960938 | 2.2137680053710938 | [0.04098546] | [0.02147245] | [0.00464214] | [0.07832833] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5068s, training loss at epoch 56: 2.1686
# using time 0.4718s, training loss at epoch 57: 2.1105
# using time 0.4636s, training loss at epoch 58: 2.0785
# using time 0.4859s, training loss at epoch 59: 2.0755
# +-------+-------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# |   60  | 0.491055965423584 | 1.7995481491088867 | 2.0127475261688232 | [0.04087841] | [0.02146372] | [0.0046046] | [0.07732733] |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# using time 0.4669s, training loss at epoch 61: 2.0124
# using time 0.4870s, training loss at epoch 62: 2.0078
# using time 0.4929s, training loss at epoch 63: 1.9594
# using time 0.4848s, training loss at epoch 64: 1.8695
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   65  | 0.5255544185638428 | 1.8035023212432861 | 1.8405776023864746 | [0.04130136] | [0.02167637] | [0.00462963] | [0.07782783] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4447s, training loss at epoch 66: 1.8539
# using time 0.4569s, training loss at epoch 67: 1.8158
# using time 0.4739s, training loss at epoch 68: 1.7846
# using time 0.4949s, training loss at epoch 69: 1.7520
# +-------+-------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   70  | 0.490628719329834 | 1.828730583190918 | 1.7424832582473755 | [0.04205926] | [0.02197795] | [0.00467968] | [0.07832833] |
# +-------+-------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5041s, training loss at epoch 71: 1.6702
# using time 0.4876s, training loss at epoch 72: 1.6911
# using time 0.4601s, training loss at epoch 73: 1.6705
# using time 0.4968s, training loss at epoch 74: 1.6384
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   75  | 0.45857834815979004 | 1.8542401790618896 | 1.6060682535171509 | [0.04189838] | [0.02200687] | [0.00461712] | [0.07757758] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4994s, training loss at epoch 76: 1.6153
# using time 0.4805s, training loss at epoch 77: 1.5789
# using time 0.5210s, training loss at epoch 78: 1.5706
# using time 0.4781s, training loss at epoch 79: 1.5111
# +-------+---------------------+-------------------+-------------------+-------------+--------------+-------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall   |     ndcg     |  precision  |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+-------------+--------------+-------------+--------------+
# |   80  | 0.46857309341430664 | 1.789637565612793 | 1.525980830192566 | [0.0429393] | [0.02220484] | [0.0047047] | [0.07832833] |
# +-------+---------------------+-------------------+-------------------+-------------+--------------+-------------+--------------+
# using time 0.5014s, training loss at epoch 81: 1.4929
# using time 0.4802s, training loss at epoch 82: 1.4696
# using time 0.4554s, training loss at epoch 83: 1.4904
# using time 0.5027s, training loss at epoch 84: 1.4415
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# |   85  | 0.47211432456970215 | 1.7945444583892822 | 1.4398707151412964 | [0.04206283] | [0.02194718] | [0.0046046] | [0.07607608] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# using time 0.5046s, training loss at epoch 86: 1.4052
# using time 0.4818s, training loss at epoch 87: 1.3795
# using time 0.5365s, training loss at epoch 88: 1.4065
# using time 0.4745s, training loss at epoch 89: 1.3824
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   90  | 0.5009105205535889 | 1.869612455368042 | 1.355778455734253 | [0.04219015] | [0.02191965] | [0.00464214] | [0.07632633] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.5186s, training loss at epoch 91: 1.3088
# using time 0.4825s, training loss at epoch 92: 1.3026
# using time 0.4933s, training loss at epoch 93: 1.3063
# using time 0.4829s, training loss at epoch 94: 1.2578
# +-------+---------------------+------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |  tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+------------------+-------------------+--------------+--------------+--------------+--------------+
# |   95  | 0.49567079544067383 | 1.78023099899292 | 1.254549264907837 | [0.04185428] | [0.02190237] | [0.00462963] | [0.07657658] |
# +-------+---------------------+------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.4851s, training loss at epoch 96: 1.2162
# using time 0.4561s, training loss at epoch 97: 1.2394
# using time 0.4238s, training loss at epoch 98: 1.2155
# using time 0.5402s, training loss at epoch 99: 1.1800
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  100  | 0.4588742256164551 | 1.9226725101470947 | 1.210059642791748 | [0.04283721] | [0.02219167] | [0.00471722] | [0.07782783] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.4737s, training loss at epoch 101: 1.1531
# using time 0.4682s, training loss at epoch 102: 1.1935
# using time 0.5047s, training loss at epoch 103: 1.1892
# using time 0.5182s, training loss at epoch 104: 1.1902
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |  105  | 0.5223355293273926 | 1.910670280456543 | 1.139447808265686 | [0.04349968] | [0.02238696] | [0.00475475] | [0.07832833] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.7284s, training loss at epoch 106: 1.1465
# using time 0.7054s, training loss at epoch 107: 1.1373
# using time 0.4931s, training loss at epoch 108: 1.1317
# using time 0.5421s, training loss at epoch 109: 1.1007
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  110  | 0.5826833248138428 | 2.4030654430389404 | 1.092699408531189 | [0.04292619] | [0.02235791] | [0.00471722] | [0.07732733] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.6662s, training loss at epoch 111: 1.1000
# using time 0.5210s, training loss at epoch 112: 1.1034
# using time 0.4632s, training loss at epoch 113: 1.0743
# using time 0.4668s, training loss at epoch 114: 1.0675
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  115  | 0.46795034408569336 | 2.3199875354766846 | 1.0224465131759644 | [0.04400614] | [0.02268598] | [0.00479229] | [0.07857858] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5029s, training loss at epoch 116: 1.0564
# using time 0.5118s, training loss at epoch 117: 1.0196
# using time 0.4742s, training loss at epoch 118: 1.0229
# using time 0.5022s, training loss at epoch 119: 1.0265
# +-------+-------------------+--------------------+-----------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |       Loss      |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+--------------------+-----------------+--------------+--------------+--------------+--------------+
# |  120  | 0.532494068145752 | 2.6524641513824463 | 1.0096355676651 | [0.04371221] | [0.02275098] | [0.00481732] | [0.07857858] |
# +-------+-------------------+--------------------+-----------------+--------------+--------------+--------------+--------------+
# using time 0.5427s, training loss at epoch 121: 0.9799
# using time 0.6289s, training loss at epoch 122: 0.9865
# using time 0.5521s, training loss at epoch 123: 0.9744
# using time 0.5972s, training loss at epoch 124: 0.9514
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  125  | 0.45832324028015137 | 1.8700151443481445 | 0.9472846388816833 | [0.04441291] | [0.02289649] | [0.00485485] | [0.07882883] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.6438s, training loss at epoch 126: 0.9959
# using time 0.6392s, training loss at epoch 127: 0.9637
# using time 0.7092s, training loss at epoch 128: 0.9520
# using time 0.7016s, training loss at epoch 129: 0.9377
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  130  | 0.7046747207641602 | 1.8668415546417236 | 0.9169975519180298 | [0.04382899] | [0.02265231] | [0.00481732] | [0.07757758] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.6551s, training loss at epoch 131: 0.9172
# using time 0.6870s, training loss at epoch 132: 0.8879
# using time 0.6990s, training loss at epoch 133: 0.8819
# using time 0.6686s, training loss at epoch 134: 0.8742
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  135  | 0.6806774139404297 | 1.8753361701965332 | 0.8791331648826599 | [0.04360972] | [0.02269603] | [0.00474224] | [0.07682683] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.6861s, training loss at epoch 136: 0.8635
# using time 0.5623s, training loss at epoch 137: 0.8824
# using time 0.4891s, training loss at epoch 138: 0.8420
# using time 0.5494s, training loss at epoch 139: 0.8454
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  140  | 0.5810098648071289 | 2.250797986984253 | 0.8645429015159607 | [0.04361707] | [0.02246034] | [0.00474224] | [0.07582583] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5703s, training loss at epoch 141: 0.8716
# using time 0.5728s, training loss at epoch 142: 0.8290
# using time 0.4791s, training loss at epoch 143: 0.8207
# using time 0.4682s, training loss at epoch 144: 0.8076
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  145  | 0.5410325527191162 | 2.2794711589813232 | 0.8066590428352356 | [0.04327766] | [0.02240425] | [0.00469219] | [0.07507508] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.6212s, training loss at epoch 146: 0.8034
# using time 0.5009s, training loss at epoch 147: 0.7957
# using time 0.6418s, training loss at epoch 148: 0.8082
# using time 0.5347s, training loss at epoch 149: 0.7817
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  150  | 0.5315370559692383 | 2.535181999206543 | 0.7870030403137207 | [0.04364122] | [0.02269023] | [0.00469219] | [0.07507508] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4837s, training loss at epoch 151: 0.8038
# using time 0.5778s, training loss at epoch 152: 0.7890
# using time 0.4613s, training loss at epoch 153: 0.7481
# using time 0.5500s, training loss at epoch 154: 0.7538
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  155  | 0.5741589069366455 | 1.868281602859497 | 0.7809549570083618 | [0.04387237] | [0.02255629] | [0.00466717] | [0.07532533] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5963s, training loss at epoch 156: 0.7282
# using time 0.6329s, training loss at epoch 157: 0.7653
# using time 0.6851s, training loss at epoch 158: 0.7379
# using time 0.6781s, training loss at epoch 159: 0.7707
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# |  160  | 0.6811881065368652 | 1.8542275428771973 | 0.7103497982025146 | [0.04377436] | [0.02252509] | [0.0047047] | [0.07507508] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# using time 0.7254s, training loss at epoch 161: 0.7479
# using time 0.6952s, training loss at epoch 162: 0.7290
# using time 0.6939s, training loss at epoch 163: 0.7106
# using time 0.7105s, training loss at epoch 164: 0.7296
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  165  | 0.6882297992706299 | 1.8746018409729004 | 0.7231885194778442 | [0.04389918] | [0.02255155] | [0.00469219] | [0.07557558] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.6300s, training loss at epoch 166: 0.7403
# using time 0.5497s, training loss at epoch 167: 0.7485
# using time 0.4613s, training loss at epoch 168: 0.6925
# using time 0.4873s, training loss at epoch 169: 0.6856
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  170  | 0.6857264041900635 | 2.3543307781219482 | 0.6750398874282837 | [0.04412003] | [0.02265451] | [0.00469219] | [0.07507508] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.6278s, training loss at epoch 171: 0.6835
# using time 0.4607s, training loss at epoch 172: 0.6663
# using time 0.3280s, training loss at epoch 173: 0.6744
# using time 0.3766s, training loss at epoch 174: 0.6791
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  175  | 0.39864039421081543 | 2.2438833713531494 | 0.6520029306411743 | [0.04392699] | [0.02261164] | [0.00466717] | [0.07507508] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# Early stopping is trigger at step: 10 log:0.04392699019892008
# early stopping at 175, recall@20:0.0444
