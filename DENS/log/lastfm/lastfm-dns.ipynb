# %%
# %load main.py
import os
import random

import torch
import numpy as np

from time import time
from tqdm import tqdm
from copy import deepcopy
import logging
from prettytable import PrettyTable

from utils.parser import parse_args
from utils.data_loader import load_data
from utils.evaluate import test
from utils.helper import early_stopping

n_users = 0
n_items = 0


def get_feed_dict(train_entity_pairs, train_pos_set, start, end, n_negs=1):

    def sampling(user_item, train_set, n):
        neg_items = []
        for user, _ in user_item.cpu().numpy():
            user = int(user)
            negitems = []
            for i in range(n):  # sample n times
                while True:
                    negitem = random.choice(range(n_items))
                    if negitem not in train_set[user]:
                        break
                negitems.append(negitem)
            neg_items.append(negitems)
        return neg_items

    feed_dict = {}
    entity_pairs = train_entity_pairs[start:end]
    feed_dict['users'] = entity_pairs[:, 0]
    feed_dict['pos_items'] = entity_pairs[:, 1]
    feed_dict['neg_items'] = torch.LongTensor(sampling(entity_pairs,
                                                       train_pos_set,
                                                       n_negs*K)).to(device)
    return feed_dict


if __name__ == '__main__':
    """fix the random seed"""
    seed = 2020
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    """read args"""
    global args, device
    args = parse_args()
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)
    device = torch.device("cuda:0") if args.cuda else torch.device("cpu")

    """build dataset"""
    train_cf, user_dict, n_params, norm_mat = load_data(args)
    train_cf_size = len(train_cf)
    train_cf = torch.LongTensor(np.array([[cf[0], cf[1]] for cf in train_cf], np.int32))

    n_users = n_params['n_users']
    n_items = n_params['n_items']
    n_negs = args.n_negs
    K = args.K

    """define model"""
    from modules.LightGCN import LightGCN
    if args.gnn == 'lightgcn':
        model = LightGCN(n_params, args, norm_mat).to(device)

    """define optimizer"""
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    cur_best_pre_0 = 0
    stopping_step = 0
    should_stop = False

    print("start training ...")
    for epoch in range(args.epoch):
        # shuffle training data
        train_cf_ = train_cf
        index = np.arange(len(train_cf_))
        np.random.shuffle(index)
        train_cf_ = train_cf_[index].to(device)

        """training"""
        model.train()
        loss, s = 0, 0
        hits = 0
        train_s_t = time()
        while s + args.batch_size <= len(train_cf):
            batch = get_feed_dict(train_cf_,
                                  user_dict['train_user_set'],
                                  s, s + args.batch_size,
                                  n_negs)

            batch_loss, _, _ = model(epoch, batch)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            loss += batch_loss
            s += args.batch_size

        train_e_t = time()

        if epoch % 5 == 0:
            """testing"""

            train_res = PrettyTable()
            train_res.field_names = ["Epoch", "training time(s)", "tesing time(s)", "Loss", "recall", "ndcg", "precision", "hit_ratio"]

            model.eval()
            test_s_t = time()
            test_ret = test(model, user_dict, n_params, mode='test')
            test_e_t = time()
            train_res.add_row(
                [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), test_ret['recall'], test_ret['ndcg'],
                 test_ret['precision'], test_ret['hit_ratio']])

            if user_dict['valid_user_set'] is None:
                valid_ret = test_ret
            else:
                test_s_t = time()
                valid_ret = test(model, user_dict, n_params, mode='valid')
                test_e_t = time()
                train_res.add_row(
                    [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), valid_ret['recall'], valid_ret['ndcg'],
                     valid_ret['precision'], valid_ret['hit_ratio']])
            print(train_res)

            # *********************************************************
            # early stopping when cur_best_pre_0 is decreasing for 10 successive steps.
            cur_best_pre_0, stopping_step, should_stop = early_stopping(valid_ret['recall'][0], cur_best_pre_0,
                                                                        stopping_step, expected_order='acc',
                                                                        flag_step=10)
            if should_stop:
                break

            """save weight"""
            if valid_ret['recall'][0] == cur_best_pre_0 and args.save:
                torch.save(model.state_dict(), args.out_dir + 'model_' + '.ckpt')
        else:
            # logging.info('training loss at epoch %d: %f' % (epoch, loss.item()))
            print('using time %.4fs, training loss at epoch %d: %.4f' % (train_e_t - train_s_t, epoch, loss.item()))

    print('early stopping at %d, recall@20:%.4f' % (epoch, cur_best_pre_0))
# Out:
# reading train and test user-item set ...
# building the adj mat ...
# {'n_users': 640, 'n_items': 4165}
# loading over ...
# start training ...
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   0   | 0.27814292907714844 | 2.192070722579956 | 4.153146266937256 | [0.01520858] | [0.01429468] | [0.01182609] | [0.10608696] |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.6289s, training loss at epoch 1: 4.1454
# using time 0.4771s, training loss at epoch 2: 4.1320
# using time 0.4620s, training loss at epoch 3: 4.1112
# using time 0.2787s, training loss at epoch 4: 4.0815
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   5   | 0.3725135326385498 | 1.3239576816558838 | 4.041702747344971 | [0.09192346] | [0.08755588] | [0.04826087] | [0.31652174] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.3152s, training loss at epoch 6: 3.9886
# using time 0.4064s, training loss at epoch 7: 3.9256
# using time 0.3552s, training loss at epoch 8: 3.8521
# using time 0.2410s, training loss at epoch 9: 3.7637
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   10  | 0.23969364166259766 | 1.3737616539001465 | 3.673449993133545 | [0.09258108] | [0.08798248] | [0.04817391] | [0.31826087] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2566s, training loss at epoch 11: 3.5763
# using time 0.3757s, training loss at epoch 12: 3.4818
# using time 0.3771s, training loss at epoch 13: 3.3832
# using time 0.3388s, training loss at epoch 14: 3.2997
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   15  | 0.24210619926452637 | 1.3057663440704346 | 3.1983063220977783 | [0.09124756] | [0.08742729] | [0.04826087] | [0.31826087] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2743s, training loss at epoch 16: 3.1369
# using time 0.2356s, training loss at epoch 17: 3.0710
# using time 0.2439s, training loss at epoch 18: 2.9961
# using time 0.2703s, training loss at epoch 19: 2.9203
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   20  | 0.30675792694091797 | 1.2398772239685059 | 2.889732837677002 | [0.09006649] | [0.08609945] | [0.04782609] | [0.31478261] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.3507s, training loss at epoch 21: 2.8274
# using time 0.2267s, training loss at epoch 22: 2.8264
# using time 0.2508s, training loss at epoch 23: 2.7700
# using time 0.3862s, training loss at epoch 24: 2.7010
# +-------+---------------------+-----------------+------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |  tesing time(s) |       Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-----------------+------------------+--------------+--------------+--------------+--------------+
# |   25  | 0.37650513648986816 | 1.3275146484375 | 2.71067476272583 | [0.08915608] | [0.08507995] | [0.04669565] | [0.31130435] |
# +-------+---------------------+-----------------+------------------+--------------+--------------+--------------+--------------+
# using time 0.3342s, training loss at epoch 26: 2.6613
# using time 0.2421s, training loss at epoch 27: 2.6295
# using time 0.2330s, training loss at epoch 28: 2.5913
# using time 0.3725s, training loss at epoch 29: 2.5923
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   30  | 0.40479397773742676 | 1.0649821758270264 | 2.5413272380828857 | [0.09075084] | [0.08582129] | [0.04686957] | [0.31304348] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2668s, training loss at epoch 31: 2.5107
# using time 0.2609s, training loss at epoch 32: 2.4838
# using time 0.2967s, training loss at epoch 33: 2.4408
# using time 0.3916s, training loss at epoch 34: 2.4184
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   35  | 0.3938944339752197 | 1.3549284934997559 | 2.4105453491210938 | [0.09000904] | [0.08569619] | [0.04678261] | [0.31478261] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3215s, training loss at epoch 36: 2.3764
# using time 0.2390s, training loss at epoch 37: 2.3731
# using time 0.2123s, training loss at epoch 38: 2.3099
# using time 0.2132s, training loss at epoch 39: 2.3312
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   40  | 0.26898932456970215 | 1.8569481372833252 | 2.3007164001464844 | [0.09039016] | [0.08585258] | [0.04695652] | [0.31652174] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3618s, training loss at epoch 41: 2.2418
# using time 0.4604s, training loss at epoch 42: 2.2396
# using time 0.4182s, training loss at epoch 43: 2.2305
# using time 0.4343s, training loss at epoch 44: 2.1969
# +-------+--------------------+-------------------+-------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+-------------+--------------+--------------+
# |   45  | 0.3648533821105957 | 2.215977191925049 | 2.178584098815918 | [0.09006332] | [0.0855752] | [0.04756522] | [0.31652174] |
# +-------+--------------------+-------------------+-------------------+--------------+-------------+--------------+--------------+
# using time 0.4082s, training loss at epoch 46: 2.1675
# using time 0.3796s, training loss at epoch 47: 2.1290
# using time 0.5543s, training loss at epoch 48: 2.1020
# using time 0.4627s, training loss at epoch 49: 2.0760
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   50  | 0.5627434253692627 | 2.394721269607544 | 2.0608396530151367 | [0.09267205] | [0.08630028] | [0.04869565] | [0.32347826] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.6810s, training loss at epoch 51: 2.0455
# using time 0.4475s, training loss at epoch 52: 2.0246
# using time 0.4265s, training loss at epoch 53: 2.0086
# using time 0.4382s, training loss at epoch 54: 1.9887
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   55  | 0.5346848964691162 | 2.611859083175659 | 1.9978820085525513 | [0.09393476] | [0.08766283] | [0.04930435] | [0.32695652] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5501s, training loss at epoch 56: 1.9598
# using time 0.5411s, training loss at epoch 57: 1.9286
# using time 0.6779s, training loss at epoch 58: 1.8898
# using time 0.3540s, training loss at epoch 59: 1.8968
# +-------+-------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)  |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# |   60  | 0.264415979385376 | 2.544848680496216 | 1.8460770845413208 | [0.0928982] | [0.08761773] | [0.04973913] | [0.32695652] |
# +-------+-------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.4617s, training loss at epoch 61: 1.8711
# using time 0.6022s, training loss at epoch 62: 1.8042
# using time 0.4899s, training loss at epoch 63: 1.8312
# using time 0.4632s, training loss at epoch 64: 1.8131
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |   65  | 0.43919968605041504 | 1.6229681968688965 | 1.8002110719680786 | [0.09770451] | [0.0899735] | [0.05104348] | [0.33391304] |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.4523s, training loss at epoch 66: 1.7810
# using time 0.4602s, training loss at epoch 67: 1.7444
# using time 0.3161s, training loss at epoch 68: 1.7241
# using time 0.2370s, training loss at epoch 69: 1.7045
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   70  | 0.2439250946044922 | 2.098717451095581 | 1.6740151643753052 | [0.09876092] | [0.09085248] | [0.05173913] | [0.33391304] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5464s, training loss at epoch 71: 1.6729
# using time 0.3167s, training loss at epoch 72: 1.6381
# using time 0.2134s, training loss at epoch 73: 1.6543
# using time 0.3289s, training loss at epoch 74: 1.6338
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   75  | 0.4056529998779297 | 1.651871681213379 | 1.6033754348754883 | [0.09858481] | [0.09161032] | [0.05173913] | [0.33217391] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3858s, training loss at epoch 76: 1.5876
# using time 0.4513s, training loss at epoch 77: 1.6026
# using time 0.4524s, training loss at epoch 78: 1.5519
# using time 0.4255s, training loss at epoch 79: 1.5488
# +-------+---------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# |   80  | 0.29177188873291016 | 1.5256049633026123 | 1.515053391456604 | [0.0996802] | [0.09231209] | [0.05295652] | [0.33565217] |
# +-------+---------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# using time 0.2483s, training loss at epoch 81: 1.5124
# using time 0.2237s, training loss at epoch 82: 1.4975
# using time 0.3196s, training loss at epoch 83: 1.5076
# using time 0.4197s, training loss at epoch 84: 1.4673
# +-------+---------------------+-------------------+--------------------+--------------+-------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg    | precision |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+-------------+-----------+--------------+
# |   85  | 0.37442708015441895 | 1.273561954498291 | 1.4477882385253906 | [0.10215955] | [0.0951643] |  [0.054]  | [0.33913043] |
# +-------+---------------------+-------------------+--------------------+--------------+-------------+-----------+--------------+
# using time 0.3353s, training loss at epoch 86: 1.4544
# using time 0.2267s, training loss at epoch 87: 1.4534
# using time 0.2195s, training loss at epoch 88: 1.3879
# using time 0.3838s, training loss at epoch 89: 1.3992
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   90  | 0.46648526191711426 | 1.884589433670044 | 1.3693313598632812 | [0.10290814] | [0.09602097] | [0.05452174] | [0.34086957] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4105s, training loss at epoch 91: 1.3731
# using time 0.3801s, training loss at epoch 92: 1.3294
# using time 0.2959s, training loss at epoch 93: 1.3266
# using time 0.4661s, training loss at epoch 94: 1.3410
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+-------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio  |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+-------------+
# |   95  | 0.3884463310241699 | 2.0836751461029053 | 1.2751257419586182 | [0.10159187] | [0.0967793] | [0.05495652] | [0.3426087] |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+-------------+
# using time 0.3316s, training loss at epoch 96: 1.3037
# using time 0.2865s, training loss at epoch 97: 1.2968
# using time 0.4030s, training loss at epoch 98: 1.2595
# using time 0.4865s, training loss at epoch 99: 1.2789
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  100  | 0.43477439880371094 | 1.727527141571045 | 1.2521851062774658 | [0.10341318] | [0.09776345] | [0.05565217] | [0.34608696] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4404s, training loss at epoch 101: 1.2464
# using time 0.3388s, training loss at epoch 102: 1.2166
# using time 0.2538s, training loss at epoch 103: 1.1977
# using time 0.3184s, training loss at epoch 104: 1.1954
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  105  | 0.35431599617004395 | 1.2927379608154297 | 1.1962839365005493 | [0.10336646] | [0.09811501] | [0.05556522] | [0.34956522] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3869s, training loss at epoch 106: 1.1844
# using time 0.4395s, training loss at epoch 107: 1.1558
# using time 0.3640s, training loss at epoch 108: 1.1573
# using time 0.2715s, training loss at epoch 109: 1.1402
# +-------+--------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# |  110  | 0.3100302219390869 | 1.465339183807373 | 1.1349331140518188 | [0.1035177] | [0.09919308] | [0.05608696] | [0.34956522] |
# +-------+--------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.3192s, training loss at epoch 111: 1.1213
# using time 0.4337s, training loss at epoch 112: 1.1121
# using time 0.3707s, training loss at epoch 113: 1.1007
# using time 0.2994s, training loss at epoch 114: 1.0783
# +-------+---------------------+--------------------+------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |       Loss       |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+------------------+--------------+-------------+--------------+--------------+
# |  115  | 0.26987695693969727 | 2.0210788249969482 | 1.07949697971344 | [0.10423241] | [0.1001834] | [0.05643478] | [0.34956522] |
# +-------+---------------------+--------------------+------------------+--------------+-------------+--------------+--------------+
# using time 0.3214s, training loss at epoch 116: 1.0693
# using time 0.2416s, training loss at epoch 117: 1.0550
# using time 0.4444s, training loss at epoch 118: 1.0598
# using time 0.6917s, training loss at epoch 119: 1.0454
# +-------+-------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+-------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |  120  | 0.823436975479126 | 1.9523661136627197 | 1.0177682638168335 | [0.10349339] | [0.0996888] | [0.05591304] | [0.34782609] |
# +-------+-------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.5391s, training loss at epoch 121: 1.0117
# using time 0.4175s, training loss at epoch 122: 1.0352
# using time 0.3907s, training loss at epoch 123: 0.9817
# using time 0.2930s, training loss at epoch 124: 0.9722
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  125  | 0.2499382495880127 | 1.8912885189056396 | 0.9614285826683044 | [0.1061957] | [0.10117224] | [0.05634783] | [0.35304348] |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2817s, training loss at epoch 126: 0.9624
# using time 0.3347s, training loss at epoch 127: 0.9691
# using time 0.6125s, training loss at epoch 128: 0.9717
# using time 0.4793s, training loss at epoch 129: 0.9840
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  130  | 0.43516993522644043 | 1.8929924964904785 | 0.9381031394004822 | [0.10654883] | [0.10169069] | [0.05634783] | [0.35130435] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3182s, training loss at epoch 131: 0.9047
# using time 0.3416s, training loss at epoch 132: 0.9101
# using time 0.2985s, training loss at epoch 133: 0.9172
# using time 0.3842s, training loss at epoch 134: 0.8888
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  135  | 0.6236991882324219 | 2.0675859451293945 | 0.9044003486633301 | [0.10522056] | [0.10091811] | [0.05626087] | [0.35304348] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5597s, training loss at epoch 136: 0.8812
# using time 0.3923s, training loss at epoch 137: 0.8795
# using time 0.2725s, training loss at epoch 138: 0.8666
# using time 0.3789s, training loss at epoch 139: 0.8642
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  140  | 0.44706130027770996 | 1.8474252223968506 | 0.831681489944458 | [0.10777767] | [0.10224609] | [0.05686957] | [0.35652174] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.5851s, training loss at epoch 141: 0.8692
# using time 1.4501s, training loss at epoch 142: 0.8437
# using time 0.8223s, training loss at epoch 143: 0.8022
# using time 0.4876s, training loss at epoch 144: 0.8361
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  145  | 0.4133436679840088 | 3.455373764038086 | 0.8441004753112793 | [0.10727299] | [0.10172141] | [0.05643478] | [0.35826087] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3088s, training loss at epoch 146: 0.8097
# using time 0.2357s, training loss at epoch 147: 0.8077
# using time 0.3840s, training loss at epoch 148: 0.8070
# using time 0.5166s, training loss at epoch 149: 0.8014
# +-------+--------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# |  150  | 0.6812434196472168 | 2.729287624359131 | 0.7916152477264404 | [0.10708669] | [0.1020011] | [0.05634783] | [0.35304348] |
# +-------+--------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.6067s, training loss at epoch 151: 0.7845
# using time 0.3184s, training loss at epoch 152: 0.7712
# using time 0.2437s, training loss at epoch 153: 0.7779
# using time 0.3625s, training loss at epoch 154: 0.7738
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  155  | 0.5319104194641113 | 1.8736097812652588 | 0.7665796875953674 | [0.10839642] | [0.10264077] | [0.05678261] | [0.35478261] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5125s, training loss at epoch 156: 0.7432
# using time 0.4423s, training loss at epoch 157: 0.7395
# using time 0.4459s, training loss at epoch 158: 0.7336
# using time 0.3500s, training loss at epoch 159: 0.7315
# +-------+---------------------+-------------------+-------------------+--------------+------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |    ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+--------------+------------+--------------+--------------+
# |  160  | 0.24728178977966309 | 2.234262228012085 | 0.724768340587616 | [0.10757192] | [0.102283] | [0.05634783] | [0.35304348] |
# +-------+---------------------+-------------------+-------------------+--------------+------------+--------------+--------------+
# using time 0.2820s, training loss at epoch 161: 0.7214
# using time 0.2527s, training loss at epoch 162: 0.7082
# using time 0.4958s, training loss at epoch 163: 0.7092
# using time 0.4250s, training loss at epoch 164: 0.6746
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |  165  | 0.6901092529296875 | 2.0994582176208496 | 0.7008529305458069 | [0.10698325] | [0.1019276] | [0.05626087] | [0.35130435] |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.5545s, training loss at epoch 166: 0.6920
# using time 0.2734s, training loss at epoch 167: 0.6998
# using time 0.2514s, training loss at epoch 168: 0.6518
# using time 0.2588s, training loss at epoch 169: 0.6674
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  170  | 0.43633580207824707 | 1.7123334407806396 | 0.6669275760650635 | [0.10764853] | [0.10194347] | [0.05643478] | [0.35304348] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.5339s, training loss at epoch 171: 0.6766
# using time 0.4698s, training loss at epoch 172: 0.6851
# using time 0.4762s, training loss at epoch 173: 0.6479
# using time 0.4477s, training loss at epoch 174: 0.6439
# +-------+---------------------+--------------------+--------------------+--------------+------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |    ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+------------+--------------+--------------+
# |  175  | 0.32858872413635254 | 1.0429832935333252 | 0.6444342136383057 | [0.10788583] | [0.102448] | [0.05678261] | [0.35652174] |
# +-------+---------------------+--------------------+--------------------+--------------+------------+--------------+--------------+
# using time 0.2716s, training loss at epoch 176: 0.6427
# using time 0.2669s, training loss at epoch 177: 0.6403
# using time 0.2766s, training loss at epoch 178: 0.6184
# using time 0.2957s, training loss at epoch 179: 0.6363
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  180  | 0.3144516944885254 | 1.1141858100891113 | 0.6202803254127502 | [0.10715186] | [0.10237837] | [0.05686957] | [0.35478261] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2923s, training loss at epoch 181: 0.6131
# using time 0.2791s, training loss at epoch 182: 0.6181
# using time 0.2664s, training loss at epoch 183: 0.5981
# using time 0.2653s, training loss at epoch 184: 0.5912
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  185  | 0.26697778701782227 | 1.178755521774292 | 0.5845053195953369 | [0.10706445] | [0.10261566] | [0.05686957] | [0.35304348] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2929s, training loss at epoch 186: 0.5881
# using time 0.2589s, training loss at epoch 187: 0.5947
# using time 0.2739s, training loss at epoch 188: 0.5876
# using time 0.2321s, training loss at epoch 189: 0.5940
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  190  | 0.25538063049316406 | 1.8599660396575928 | 0.5884722471237183 | [0.10610541] | [0.10182592] | [0.05634783] | [0.35304348] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3643s, training loss at epoch 191: 0.5807
# using time 0.3006s, training loss at epoch 192: 0.5698
# using time 0.3798s, training loss at epoch 193: 0.5772
# using time 0.5682s, training loss at epoch 194: 0.5759
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  195  | 0.39557480812072754 | 1.6961209774017334 | 0.5652512311935425 | [0.10618261] | [0.10200622] | [0.05652174] | [0.35304348] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3256s, training loss at epoch 196: 0.5432
# using time 0.3629s, training loss at epoch 197: 0.5505
# using time 0.4313s, training loss at epoch 198: 0.5376
# using time 0.5933s, training loss at epoch 199: 0.5325
# +-------+---------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# |  200  | 0.43787550926208496 | 2.094268560409546 | 0.5348901748657227 | [0.1058871] | [0.10219963] | [0.05634783] | [0.35304348] |
# +-------+---------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.3981s, training loss at epoch 201: 0.5552
# using time 0.3833s, training loss at epoch 202: 0.5303
# using time 0.2868s, training loss at epoch 203: 0.5288
# using time 0.3078s, training loss at epoch 204: 0.5164
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  205  | 0.5123229026794434 | 1.8915352821350098 | 0.5181593894958496 | [0.10679216] | [0.10263433] | [0.05678261] | [0.35652174] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# Early stopping is trigger at step: 10 log:0.10679215945196437
# early stopping at 205, recall@20:0.1084
