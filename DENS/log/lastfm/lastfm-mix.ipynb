# %%
# %load main.py
import os
import random

import torch
import numpy as np

from time import time
from tqdm import tqdm
from copy import deepcopy
import logging
from prettytable import PrettyTable

from utils.parser import parse_args
from utils.data_loader import load_data
from utils.evaluate import test
from utils.helper import early_stopping

n_users = 0
n_items = 0


def get_feed_dict(train_entity_pairs, train_pos_set, start, end, n_negs=1):

    def sampling(user_item, train_set, n):
        neg_items = []
        for user, _ in user_item.cpu().numpy():
            user = int(user)
            negitems = []
            for i in range(n):  # sample n times
                while True:
                    negitem = random.choice(range(n_items))
                    if negitem not in train_set[user]:
                        break
                negitems.append(negitem)
            neg_items.append(negitems)
        return neg_items

    feed_dict = {}
    entity_pairs = train_entity_pairs[start:end]
    feed_dict['users'] = entity_pairs[:, 0]
    feed_dict['pos_items'] = entity_pairs[:, 1]
    feed_dict['neg_items'] = torch.LongTensor(sampling(entity_pairs,
                                                       train_pos_set,
                                                       n_negs*K)).to(device)
    return feed_dict


if __name__ == '__main__':
    """fix the random seed"""
    seed = 2020
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    """read args"""
    global args, device
    args = parse_args()
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)
    device = torch.device("cuda:0") if args.cuda else torch.device("cpu")

    """build dataset"""
    train_cf, user_dict, n_params, norm_mat = load_data(args)
    train_cf_size = len(train_cf)
    train_cf = torch.LongTensor(np.array([[cf[0], cf[1]] for cf in train_cf], np.int32))

    n_users = n_params['n_users']
    n_items = n_params['n_items']
    n_negs = args.n_negs
    K = args.K

    """define model"""
    from modules.LightGCN import LightGCN
    if args.gnn == 'lightgcn':
        model = LightGCN(n_params, args, norm_mat).to(device)

    """define optimizer"""
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    cur_best_pre_0 = 0
    stopping_step = 0
    should_stop = False

    print("start training ...")
    for epoch in range(args.epoch):
        # shuffle training data
        train_cf_ = train_cf
        index = np.arange(len(train_cf_))
        np.random.shuffle(index)
        train_cf_ = train_cf_[index].to(device)

        """training"""
        model.train()
        loss, s = 0, 0
        hits = 0
        train_s_t = time()
        while s + args.batch_size <= len(train_cf):
            batch = get_feed_dict(train_cf_,
                                  user_dict['train_user_set'],
                                  s, s + args.batch_size,
                                  n_negs)

            batch_loss, _, _ = model(epoch, batch)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            loss += batch_loss
            s += args.batch_size

        train_e_t = time()

        if epoch % 5 == 0:
            """testing"""

            train_res = PrettyTable()
            train_res.field_names = ["Epoch", "training time(s)", "tesing time(s)", "Loss", "recall", "ndcg", "precision", "hit_ratio"]

            model.eval()
            test_s_t = time()
            test_ret = test(model, user_dict, n_params, mode='test')
            test_e_t = time()
            train_res.add_row(
                [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), test_ret['recall'], test_ret['ndcg'],
                 test_ret['precision'], test_ret['hit_ratio']])

            if user_dict['valid_user_set'] is None:
                valid_ret = test_ret
            else:
                test_s_t = time()
                valid_ret = test(model, user_dict, n_params, mode='valid')
                test_e_t = time()
                train_res.add_row(
                    [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), valid_ret['recall'], valid_ret['ndcg'],
                     valid_ret['precision'], valid_ret['hit_ratio']])
            print(train_res)

            # *********************************************************
            # early stopping when cur_best_pre_0 is decreasing for 10 successive steps.
            cur_best_pre_0, stopping_step, should_stop = early_stopping(valid_ret['recall'][0], cur_best_pre_0,
                                                                        stopping_step, expected_order='acc',
                                                                        flag_step=10)
            if should_stop:
                break

            """save weight"""
            if valid_ret['recall'][0] == cur_best_pre_0 and args.save:
                torch.save(model.state_dict(), args.out_dir + 'model_' + '.ckpt')
        else:
            # logging.info('training loss at epoch %d: %f' % (epoch, loss.item()))
            print('using time %.4fs, training loss at epoch %d: %.4f' % (train_e_t - train_s_t, epoch, loss.item()))

    print('early stopping at %d, recall@20:%.4f' % (epoch, cur_best_pre_0))
# Out:
# reading train and test user-item set ...
# building the adj mat ...
# {'n_users': 640, 'n_items': 4165}
# loading over ...
# start training ...
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+-------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio  |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+-------------+
# |   0   | 0.27576303482055664 | 2.391097068786621 | 4.157106876373291 | [0.01403065] | [0.01255436] | [0.01078261] | [0.1026087] |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+-------------+
# using time 0.4458s, training loss at epoch 1: 4.1535
# using time 0.4973s, training loss at epoch 2: 4.1473
# using time 0.5312s, training loss at epoch 3: 4.1380
# using time 0.4206s, training loss at epoch 4: 4.1238
# +-------+--------------------+-------------------+-------------------+--------------+--------------+-----------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+-----------+--------------+
# |   5   | 0.3335587978363037 | 2.581906318664551 | 4.105503082275391 | [0.08977007] | [0.08632153] |  [0.048]  | [0.31304348] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+-----------+--------------+
# using time 0.6722s, training loss at epoch 6: 4.0802
# using time 0.4934s, training loss at epoch 7: 4.0510
# using time 0.3143s, training loss at epoch 8: 4.0140
# using time 0.2470s, training loss at epoch 9: 3.9692
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   10  | 0.34885239601135254 | 4.023682355880737 | 3.919245719909668 | [0.09330779] | [0.08817131] | [0.04834783] | [0.31826087] |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.5872s, training loss at epoch 11: 3.8633
# using time 1.0331s, training loss at epoch 12: 3.8105
# using time 0.6992s, training loss at epoch 13: 3.7472
# using time 0.6907s, training loss at epoch 14: 3.6832
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   15  | 0.46551060676574707 | 3.2329483032226562 | 3.6125411987304688 | [0.09164035] | [0.08752367] | [0.04826087] | [0.31652174] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2748s, training loss at epoch 16: 3.5636
# using time 0.2899s, training loss at epoch 17: 3.4974
# using time 0.6300s, training loss at epoch 18: 3.4356
# using time 0.5174s, training loss at epoch 19: 3.3683
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   20  | 0.4630246162414551 | 2.5507264137268066 | 3.3235971927642822 | [0.09071244] | [0.08641034] | [0.04808696] | [0.31652174] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2896s, training loss at epoch 21: 3.2664
# using time 0.3662s, training loss at epoch 22: 3.2484
# using time 0.4963s, training loss at epoch 23: 3.1976
# using time 0.4959s, training loss at epoch 24: 3.1339
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   25  | 0.47095823287963867 | 2.712690830230713 | 3.123351573944092 | [0.09034262] | [0.08609288] | [0.04773913] | [0.31478261] |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.3230s, training loss at epoch 26: 3.0777
# using time 0.2886s, training loss at epoch 27: 3.0478
# using time 0.4586s, training loss at epoch 28: 3.0064
# using time 0.4934s, training loss at epoch 29: 2.9937
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   30  | 0.5910582542419434 | 2.7898879051208496 | 2.953131914138794 | [0.09076291] | [0.08627261] | [0.04791304] | [0.31478261] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.3548s, training loss at epoch 31: 2.9242
# using time 0.3376s, training loss at epoch 32: 2.8908
# using time 0.4553s, training loss at epoch 33: 2.8547
# using time 0.4749s, training loss at epoch 34: 2.8283
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   35  | 0.4916043281555176 | 2.6260833740234375 | 2.8155806064605713 | [0.09068693] | [0.08620231] | [0.04791304] | [0.31652174] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3390s, training loss at epoch 36: 2.7897
# using time 0.3492s, training loss at epoch 37: 2.7903
# using time 0.3274s, training loss at epoch 38: 2.7352
# using time 0.2845s, training loss at epoch 39: 2.7508
# +-------+-------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |  tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# |   40  | 0.289966344833374 | 1.55003023147583 | 2.7224040031433105 | [0.09154553] | [0.08644362] | [0.04756522] | [0.31826087] |
# +-------+-------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3375s, training loss at epoch 41: 2.6685
# using time 0.2643s, training loss at epoch 42: 2.6723
# using time 0.2566s, training loss at epoch 43: 2.6599
# using time 0.3251s, training loss at epoch 44: 2.6394
# +-------+--------------------+--------------------+-------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+-------------+--------------+
# |   45  | 0.3467576503753662 | 1.5544300079345703 | 2.620197057723999 | [0.09172566] | [0.08606998] | [0.0473913] | [0.31826087] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+-------------+--------------+
# using time 0.3935s, training loss at epoch 46: 2.5990
# using time 0.3312s, training loss at epoch 47: 2.5640
# using time 0.2568s, training loss at epoch 48: 2.5567
# using time 0.2849s, training loss at epoch 49: 2.5338
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   50  | 0.27422142028808594 | 2.4628729820251465 | 2.5026838779449463 | [0.09340186] | [0.08621054] | [0.04721739] | [0.32173913] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4185s, training loss at epoch 51: 2.5132
# using time 0.5326s, training loss at epoch 52: 2.4972
# using time 0.3381s, training loss at epoch 53: 2.4839
# using time 0.3199s, training loss at epoch 54: 2.4632
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   55  | 0.32851624488830566 | 2.489774465560913 | 2.4712610244750977 | [0.09275283] | [0.08583356] | [0.04713043] | [0.32173913] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4795s, training loss at epoch 56: 2.4505
# using time 0.5287s, training loss at epoch 57: 2.4245
# using time 0.4200s, training loss at epoch 58: 2.3712
# using time 0.3789s, training loss at epoch 59: 2.4131
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   60  | 0.4687495231628418 | 2.5334181785583496 | 2.3408658504486084 | [0.09264041] | [0.08650162] | [0.04747826] | [0.32521739] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4778s, training loss at epoch 61: 2.3737
# using time 0.4320s, training loss at epoch 62: 2.3075
# using time 0.5067s, training loss at epoch 63: 2.3366
# using time 0.4368s, training loss at epoch 64: 2.3268
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   65  | 0.3958103656768799 | 2.4032139778137207 | 2.3049428462982178 | [0.09217381] | [0.08618549] | [0.04765217] | [0.32347826] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4674s, training loss at epoch 66: 2.3081
# using time 0.4912s, training loss at epoch 67: 2.2794
# using time 0.4521s, training loss at epoch 68: 2.2515
# using time 0.5272s, training loss at epoch 69: 2.2435
# +-------+---------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# |   70  | 0.24541282653808594 | 3.109710454940796 | 2.2202656269073486 | [0.0920597] | [0.08580764] | [0.04765217] | [0.32521739] |
# +-------+---------------------+-------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.7798s, training loss at epoch 71: 2.2289
# using time 0.2932s, training loss at epoch 72: 2.1913
# using time 0.2616s, training loss at epoch 73: 2.2026
# using time 0.4064s, training loss at epoch 74: 2.1964
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   75  | 0.5987739562988281 | 2.258349895477295 | 2.1460185050964355 | [0.09337511] | [0.08610477] | [0.04886957] | [0.32869565] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4311s, training loss at epoch 76: 2.1623
# using time 0.2705s, training loss at epoch 77: 2.1705
# using time 0.2469s, training loss at epoch 78: 2.1249
# using time 0.3292s, training loss at epoch 79: 2.1245
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   80  | 0.2995262145996094 | 1.9959473609924316 | 2.1049575805664062 | [0.09555299] | [0.08759535] | [0.04982609] | [0.33043478] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3824s, training loss at epoch 81: 2.0908
# using time 0.3359s, training loss at epoch 82: 2.0726
# using time 0.4110s, training loss at epoch 83: 2.0836
# using time 0.3915s, training loss at epoch 84: 2.0618
# +-------+--------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |       Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# |   85  | 0.2876412868499756 | 1.8434667587280273 | 2.04347562789917 | [0.09699762] | [0.08885088] | [0.05008696] | [0.33565217] |
# +-------+--------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# using time 0.3426s, training loss at epoch 86: 2.0516
# using time 0.3969s, training loss at epoch 87: 2.0390
# using time 0.2730s, training loss at epoch 88: 1.9905
# using time 0.2621s, training loss at epoch 89: 2.0006
# +-------+---------------------+--------------------+--------------------+--------------+-------------+-------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision  |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+-------------+--------------+
# |   90  | 0.27474451065063477 | 1.7747466564178467 | 1.9734423160552979 | [0.09651262] | [0.0893883] | [0.0506087] | [0.33565217] |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+-------------+--------------+
# using time 0.4173s, training loss at epoch 91: 1.9763
# using time 0.3587s, training loss at epoch 92: 1.9201
# using time 0.2396s, training loss at epoch 93: 1.9270
# using time 0.1889s, training loss at epoch 94: 1.9513
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   95  | 0.19836068153381348 | 1.8072302341461182 | 1.8918501138687134 | [0.09716242] | [0.09025968] | [0.05104348] | [0.33391304] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3272s, training loss at epoch 96: 1.9181
# using time 0.2674s, training loss at epoch 97: 1.9173
# using time 0.2756s, training loss at epoch 98: 1.8737
# using time 0.2969s, training loss at epoch 99: 1.8953
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# |  100  | 0.2855873107910156 | 1.5228002071380615 | 1.8718390464782715 | [0.09737241] | [0.09083125] | [0.0513913] | [0.33565217] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+-------------+--------------+
# using time 0.2792s, training loss at epoch 101: 1.8815
# using time 0.3014s, training loss at epoch 102: 1.8370
# using time 0.3127s, training loss at epoch 103: 1.8180
# using time 0.3112s, training loss at epoch 104: 1.8119
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+-------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio  |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+-------------+
# |  105  | 0.2883186340332031 | 1.533341646194458 | 1.8209621906280518 | [0.09867988] | [0.09203164] | [0.05191304] | [0.3373913] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+-------------+
# using time 0.2957s, training loss at epoch 106: 1.8202
# using time 0.3949s, training loss at epoch 107: 1.7754
# using time 0.4036s, training loss at epoch 108: 1.7898
# using time 0.3658s, training loss at epoch 109: 1.7744
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio  |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# |  110  | 0.30954718589782715 | 1.7860348224639893 | 1.7538690567016602 | [0.09866416] | [0.09208501] | [0.05208696] | [0.3373913] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# using time 0.3625s, training loss at epoch 111: 1.7489
# using time 0.2851s, training loss at epoch 112: 1.7304
# using time 0.4701s, training loss at epoch 113: 1.7263
# using time 0.4217s, training loss at epoch 114: 1.6981
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  115  | 0.3980991840362549 | 2.4179885387420654 | 1.7159334421157837 | [0.09869725] | [0.09277052] | [0.05295652] | [0.33217391] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4395s, training loss at epoch 116: 1.6992
# using time 0.5034s, training loss at epoch 117: 1.6797
# using time 0.3467s, training loss at epoch 118: 1.6891
# using time 0.4044s, training loss at epoch 119: 1.6863
# +-------+-------------------+--------------------+--------------------+-------------+--------------+--------------+-------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio  |
# +-------+-------------------+--------------------+--------------------+-------------+--------------+--------------+-------------+
# |  120  | 0.351285457611084 | 2.8791401386260986 | 1.6564847230911255 | [0.1025004] | [0.09498952] | [0.05382609] | [0.3373913] |
# +-------+-------------------+--------------------+--------------------+-------------+--------------+--------------+-------------+
# using time 0.5410s, training loss at epoch 121: 1.6447
# using time 0.3628s, training loss at epoch 122: 1.6594
# using time 0.3087s, training loss at epoch 123: 1.6126
# using time 0.4214s, training loss at epoch 124: 1.5978
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  125  | 0.6141982078552246 | 2.5784385204315186 | 1.592690110206604 | [0.10383545] | [0.09556649] | [0.05426087] | [0.34086957] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.3332s, training loss at epoch 126: 1.5828
# using time 0.2754s, training loss at epoch 127: 1.6019
# using time 0.3894s, training loss at epoch 128: 1.6058
# using time 0.4058s, training loss at epoch 129: 1.6167
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-------------+-------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio  |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-------------+-------------+
# |  130  | 0.46288490295410156 | 2.9925782680511475 | 1.5594274997711182 | [0.10363232] | [0.09698465] | [0.0546087] | [0.3426087] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-------------+-------------+
# using time 0.5700s, training loss at epoch 131: 1.5064
# using time 0.5128s, training loss at epoch 132: 1.5231
# using time 0.3111s, training loss at epoch 133: 1.5335
# using time 0.2410s, training loss at epoch 134: 1.5105
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  135  | 0.25714850425720215 | 2.2768876552581787 | 1.5083353519439697 | [0.10280206] | [0.09742987] | [0.05504348] | [0.34434783] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3220s, training loss at epoch 136: 1.4972
# using time 0.3472s, training loss at epoch 137: 1.4859
# using time 0.4438s, training loss at epoch 138: 1.4717
# using time 0.4323s, training loss at epoch 139: 1.4721
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  140  | 0.39107322692871094 | 1.8791465759277344 | 1.4375966787338257 | [0.10375845] | [0.09838555] | [0.05565217] | [0.34608696] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3462s, training loss at epoch 141: 1.4915
# using time 0.4028s, training loss at epoch 142: 1.4481
# using time 0.3585s, training loss at epoch 143: 1.4152
# using time 0.2313s, training loss at epoch 144: 1.4479
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  145  | 0.2987813949584961 | 1.8255202770233154 | 1.460837960243225 | [0.10368656] | [0.09861502] | [0.05565217] | [0.34608696] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.5007s, training loss at epoch 146: 1.4335
# using time 0.3213s, training loss at epoch 147: 1.4104
# using time 0.2295s, training loss at epoch 148: 1.4110
# using time 0.2997s, training loss at epoch 149: 1.3955
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  150  | 0.24651527404785156 | 1.8780498504638672 | 1.3883250951766968 | [0.10305894] | [0.09839716] | [0.05547826] | [0.34434783] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4046s, training loss at epoch 151: 1.3943
# using time 0.3547s, training loss at epoch 152: 1.3561
# using time 0.2483s, training loss at epoch 153: 1.3791
# using time 0.2749s, training loss at epoch 154: 1.3684
# +-------+-------------------+--------------------+-------------------+--------------+--------------+-----------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss       |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+-------------------+--------------------+-------------------+--------------+--------------+-----------+--------------+
# |  155  | 0.278048038482666 | 1.7000617980957031 | 1.364417314529419 | [0.10448296] | [0.09937083] |  [0.056]  | [0.34608696] |
# +-------+-------------------+--------------------+-------------------+--------------+--------------+-----------+--------------+
# using time 0.2944s, training loss at epoch 156: 1.3284
# using time 0.3221s, training loss at epoch 157: 1.3411
# using time 0.2788s, training loss at epoch 158: 1.3083
# using time 0.2749s, training loss at epoch 159: 1.3219
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  160  | 0.26212072372436523 | 1.5602707862854004 | 1.3053656816482544 | [0.10438096] | [0.09908346] | [0.05591304] | [0.34434783] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2760s, training loss at epoch 161: 1.2993
# using time 0.2933s, training loss at epoch 162: 1.2796
# using time 0.3075s, training loss at epoch 163: 1.2956
# using time 0.3032s, training loss at epoch 164: 1.2468
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  165  | 0.3153367042541504 | 1.5256476402282715 | 1.2836843729019165 | [0.10501965] | [0.09956036] | [0.05626087] | [0.34434783] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2989s, training loss at epoch 166: 1.2589
# using time 0.2773s, training loss at epoch 167: 1.2776
# using time 0.3045s, training loss at epoch 168: 1.2151
# using time 0.3150s, training loss at epoch 169: 1.2307
# +-------+---------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# |  170  | 0.30290818214416504 | 1.5204696655273438 | 1.234627366065979 | [0.1067098] | [0.09993346] | [0.05608696] | [0.34608696] |
# +-------+---------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# using time 0.2740s, training loss at epoch 171: 1.2322
# using time 0.2941s, training loss at epoch 172: 1.2590
# using time 0.3093s, training loss at epoch 173: 1.2139
# using time 0.2531s, training loss at epoch 174: 1.2237
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  175  | 0.276137113571167 | 1.6689815521240234 | 1.2050433158874512 | [0.10642079] | [0.10069158] | [0.05626087] | [0.34608696] |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3165s, training loss at epoch 176: 1.1958
# using time 0.3307s, training loss at epoch 177: 1.1951
# using time 0.2476s, training loss at epoch 178: 1.1798
# using time 0.2658s, training loss at epoch 179: 1.1818
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  180  | 0.36086225509643555 | 2.0359222888946533 | 1.1675121784210205 | [0.10667088] | [0.10079461] | [0.05626087] | [0.34782609] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.4119s, training loss at epoch 181: 1.1604
# using time 0.2621s, training loss at epoch 182: 1.1738
# using time 0.2419s, training loss at epoch 183: 1.1434
# using time 0.2417s, training loss at epoch 184: 1.1332
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  185  | 0.2583043575286865 | 1.9448800086975098 | 1.1223437786102295 | [0.10736707] | [0.10085637] | [0.05634783] | [0.34956522] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2872s, training loss at epoch 186: 1.1193
# using time 0.2180s, training loss at epoch 187: 1.1387
# using time 0.2642s, training loss at epoch 188: 1.1105
# using time 0.2378s, training loss at epoch 189: 1.1442
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# |  190  | 0.29949307441711426 | 2.4604294300079346 | 1.1303917169570923 | [0.10729089] | [0.10070468] |  [0.056]  | [0.34782609] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# using time 0.2330s, training loss at epoch 191: 1.1208
# using time 0.2296s, training loss at epoch 192: 1.1028
# using time 0.4005s, training loss at epoch 193: 1.1106
# using time 0.5026s, training loss at epoch 194: 1.1085
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |  195  | 0.43132758140563965 | 2.639120101928711 | 1.093714952468872 | [0.10719721] | [0.10073456] | [0.05582609] | [0.34782609] |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2983s, training loss at epoch 196: 1.0657
# using time 0.2272s, training loss at epoch 197: 1.0611
# using time 0.3495s, training loss at epoch 198: 1.0524
# using time 0.5410s, training loss at epoch 199: 1.0622
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# |  200  | 0.49773406982421875 | 2.4710826873779297 | 1.0514805316925049 | [0.10732894] | [0.10079624] |  [0.056]  | [0.34782609] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# using time 0.3185s, training loss at epoch 201: 1.0731
# using time 0.2711s, training loss at epoch 202: 1.0439
# using time 0.3320s, training loss at epoch 203: 1.0304
# using time 0.3971s, training loss at epoch 204: 1.0269
# +-------+--------------------+-------------------+-------------------+--------------+--------------+-----------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+-----------+--------------+
# |  205  | 0.3604776859283447 | 1.902954339981079 | 1.035309910774231 | [0.10673996] | [0.10070297] |  [0.056]  | [0.34782609] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+-----------+--------------+
# using time 0.3573s, training loss at epoch 206: 1.0199
# using time 0.3558s, training loss at epoch 207: 1.0157
# using time 0.3174s, training loss at epoch 208: 1.0438
# using time 0.2600s, training loss at epoch 209: 1.0343
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# |  210  | 0.28090858459472656 | 1.8910374641418457 | 1.0132544040679932 | [0.10661627] | [0.10088087] |  [0.056]  | [0.34782609] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# using time 0.3792s, training loss at epoch 211: 0.9860
# using time 0.3338s, training loss at epoch 212: 0.9880
# using time 0.2480s, training loss at epoch 213: 1.0136
# using time 0.3261s, training loss at epoch 214: 0.9946
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  215  | 0.42844367027282715 | 1.6177260875701904 | 0.9989116191864014 | [0.10720239] | [0.10127184] | [0.05643478] | [0.35130435] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2579s, training loss at epoch 216: 0.9835
# using time 0.2911s, training loss at epoch 217: 0.9630
# using time 0.2736s, training loss at epoch 218: 0.9681
# using time 0.2931s, training loss at epoch 219: 0.9552
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  220  | 0.23325419425964355 | 1.4587414264678955 | 0.944567859172821 | [0.10750768] | [0.10118669] | [0.05608696] | [0.35130435] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2847s, training loss at epoch 221: 0.9636
# using time 0.2836s, training loss at epoch 222: 0.9411
# using time 0.2734s, training loss at epoch 223: 0.9381
# using time 0.2568s, training loss at epoch 224: 0.9386
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  225  | 0.23524117469787598 | 1.4169659614562988 | 0.9350592494010925 | [0.1077171] | [0.10152831] | [0.05617391] | [0.35304348] |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2240s, training loss at epoch 226: 0.9303
# using time 0.2588s, training loss at epoch 227: 0.9190
# using time 0.2703s, training loss at epoch 228: 0.9082
# using time 0.2724s, training loss at epoch 229: 0.9247
# +-------+--------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |  tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# |  230  | 0.2266674041748047 | 1.44089937210083 | 0.9229951500892639 | [0.10702153] | [0.10166529] | [0.05626087] | [0.35130435] |
# +-------+--------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2869s, training loss at epoch 231: 0.8991
# using time 0.2982s, training loss at epoch 232: 0.9128
# using time 0.2480s, training loss at epoch 233: 0.8868
# using time 0.2565s, training loss at epoch 234: 0.8761
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  235  | 0.2770209312438965 | 1.4774761199951172 | 0.8888603448867798 | [0.1054873] | [0.10123902] | [0.05626087] | [0.34956522] |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2358s, training loss at epoch 236: 0.8965
# using time 0.2107s, training loss at epoch 237: 0.8677
# using time 0.2236s, training loss at epoch 238: 0.9001
# using time 0.2611s, training loss at epoch 239: 0.9137
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  240  | 0.3824176788330078 | 1.7173070907592773 | 0.8867278099060059 | [0.1058621] | [0.10115071] | [0.05617391] | [0.34782609] |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2369s, training loss at epoch 241: 0.8450
# using time 0.2155s, training loss at epoch 242: 0.8588
# using time 0.2485s, training loss at epoch 243: 0.8600
# using time 0.3267s, training loss at epoch 244: 0.8563
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  245  | 0.30408191680908203 | 1.840451955795288 | 0.8548638820648193 | [0.10525878] | [0.10098242] | [0.05591304] | [0.34782609] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3407s, training loss at epoch 246: 0.8798
# using time 0.2738s, training loss at epoch 247: 0.8720
# using time 0.3710s, training loss at epoch 248: 0.8299
# using time 0.2095s, training loss at epoch 249: 0.8184
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  250  | 0.21085858345031738 | 1.8385684490203857 | 0.8579568862915039 | [0.10585393] | [0.10118133] | [0.05634783] | [0.34956522] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3666s, training loss at epoch 251: 0.8309
# using time 0.3493s, training loss at epoch 252: 0.7976
# using time 0.2166s, training loss at epoch 253: 0.8207
# using time 0.2108s, training loss at epoch 254: 0.8267
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  255  | 0.24432635307312012 | 1.8984882831573486 | 0.8407761454582214 | [0.10574067] | [0.10106771] | [0.05626087] | [0.35304348] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2723s, training loss at epoch 256: 0.8200
# using time 0.2697s, training loss at epoch 257: 0.8040
# using time 0.2127s, training loss at epoch 258: 0.8114
# using time 0.2243s, training loss at epoch 259: 0.8290
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  260  | 0.24772334098815918 | 1.8256704807281494 | 0.8061001896858215 | [0.10571159] | [0.10128643] | [0.05626087] | [0.35304348] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2420s, training loss at epoch 261: 0.7792
# using time 0.2275s, training loss at epoch 262: 0.7974
# using time 0.2896s, training loss at epoch 263: 0.7722
# using time 0.2299s, training loss at epoch 264: 0.7852
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  265  | 0.2749669551849365 | 1.4716823101043701 | 0.7735679745674133 | [0.10608991] | [0.10175128] | [0.05634783] | [0.35478261] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2208s, training loss at epoch 266: 0.7970
# using time 0.2463s, training loss at epoch 267: 0.7689
# using time 0.2549s, training loss at epoch 268: 0.7777
# using time 0.2835s, training loss at epoch 269: 0.7601
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |  270  | 0.2498302459716797 | 1.437575340270996 | 0.7632355690002441 | [0.10597725] | [0.10136916] | [0.05617391] | [0.35478261] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2689s, training loss at epoch 271: 0.7729
# using time 0.2755s, training loss at epoch 272: 0.7799
# using time 0.2440s, training loss at epoch 273: 0.7314
# using time 0.2283s, training loss at epoch 274: 0.7332
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |  275  | 0.23371267318725586 | 1.4561927318572998 | 0.7390000224113464 | [0.10569982] | [0.1019518] | [0.05608696] | [0.35478261] |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# Early stopping is trigger at step: 10 log:0.1056998182975492
# early stopping at 275, recall@20:0.1077
