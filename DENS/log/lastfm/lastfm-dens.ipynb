# %%
# %load main.py
import os
import random

import torch
import numpy as np

from time import time
from tqdm import tqdm
from copy import deepcopy
import logging
from prettytable import PrettyTable

from utils.parser import parse_args
from utils.data_loader import load_data
from utils.evaluate import test
from utils.helper import early_stopping

n_users = 0
n_items = 0


def get_feed_dict(train_entity_pairs, train_pos_set, start, end, n_negs=1):

    def sampling(user_item, train_set, n):
        neg_items = []
        for user, _ in user_item.cpu().numpy():
            user = int(user)
            negitems = []
            for i in range(n):  # sample n times
                while True:
                    negitem = random.choice(range(n_items))
                    if negitem not in train_set[user]:
                        break
                negitems.append(negitem)
            neg_items.append(negitems)
        return neg_items

    feed_dict = {}
    entity_pairs = train_entity_pairs[start:end]
    feed_dict['users'] = entity_pairs[:, 0]
    feed_dict['pos_items'] = entity_pairs[:, 1]
    feed_dict['neg_items'] = torch.LongTensor(sampling(entity_pairs,
                                                       train_pos_set,
                                                       n_negs*K)).to(device)
    return feed_dict


if __name__ == '__main__':
    """fix the random seed"""
    seed = 2020
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    """read args"""
    global args, device
    args = parse_args()
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)
    device = torch.device("cuda:0") if args.cuda else torch.device("cpu")

    """build dataset"""
    train_cf, user_dict, n_params, norm_mat = load_data(args)
    train_cf_size = len(train_cf)
    train_cf = torch.LongTensor(np.array([[cf[0], cf[1]] for cf in train_cf], np.int32))

    n_users = n_params['n_users']
    n_items = n_params['n_items']
    n_negs = args.n_negs
    K = args.K

    """define model"""
    from modules.LightGCN import LightGCN
    if args.gnn == 'lightgcn':
        model = LightGCN(n_params, args, norm_mat).to(device)

    """define optimizer"""
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    cur_best_pre_0 = 0
    stopping_step = 0
    should_stop = False

    print("start training ...")
    for epoch in range(args.epoch):
        # shuffle training data
        train_cf_ = train_cf
        index = np.arange(len(train_cf_))
        np.random.shuffle(index)
        train_cf_ = train_cf_[index].to(device)

        """training"""
        model.train()
        loss, s = 0, 0
        hits = 0
        train_s_t = time()
        while s + args.batch_size <= len(train_cf):
            batch = get_feed_dict(train_cf_,
                                  user_dict['train_user_set'],
                                  s, s + args.batch_size,
                                  n_negs)

            batch_loss, _, _ = model(epoch, batch)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            loss += batch_loss
            s += args.batch_size

        train_e_t = time()

        if epoch % 5 == 0:
            """testing"""

            train_res = PrettyTable()
            train_res.field_names = ["Epoch", "training time(s)", "tesing time(s)", "Loss", "recall", "ndcg", "precision", "hit_ratio"]

            model.eval()
            test_s_t = time()
            test_ret = test(model, user_dict, n_params, mode='test')
            test_e_t = time()
            train_res.add_row(
                [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), test_ret['recall'], test_ret['ndcg'],
                 test_ret['precision'], test_ret['hit_ratio']])

            if user_dict['valid_user_set'] is None:
                valid_ret = test_ret
            else:
                test_s_t = time()
                valid_ret = test(model, user_dict, n_params, mode='valid')
                test_e_t = time()
                train_res.add_row(
                    [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), valid_ret['recall'], valid_ret['ndcg'],
                     valid_ret['precision'], valid_ret['hit_ratio']])
            print(train_res)

            # *********************************************************
            # early stopping when cur_best_pre_0 is decreasing for 10 successive steps.
            cur_best_pre_0, stopping_step, should_stop = early_stopping(valid_ret['recall'][0], cur_best_pre_0,
                                                                        stopping_step, expected_order='acc',
                                                                        flag_step=10)
            if should_stop:
                break

            """save weight"""
            if valid_ret['recall'][0] == cur_best_pre_0 and args.save:
                torch.save(model.state_dict(), args.out_dir + 'model_' + '.ckpt')
        else:
            # logging.info('training loss at epoch %d: %f' % (epoch, loss.item()))
            print('using time %.4fs, training loss at epoch %d: %.4f' % (train_e_t - train_s_t, epoch, loss.item()))

    print('early stopping at %d, recall@20:%.4f' % (epoch, cur_best_pre_0))
# Out:
# reading train and test user-item set ...
# building the adj mat ...
# {'n_users': 640, 'n_items': 4165}
# loading over ...
# start training ...
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+-------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg    |  precision   |  hit_ratio  |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+-------------+
# |   0   | 0.2412886619567871 | 1.3720169067382812 | 5.816640853881836 | [0.01407513] | [0.0130865] | [0.01095652] | [0.1026087] |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+-------------+
# using time 0.2541s, training loss at epoch 1: 5.8094
# using time 0.2424s, training loss at epoch 2: 5.7962
# using time 0.2447s, training loss at epoch 3: 5.7751
# using time 0.2807s, training loss at epoch 4: 5.7446
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   5   | 0.24066472053527832 | 1.397550106048584 | 5.702889919281006 | [0.08910502] | [0.08632042] | [0.04756522] | [0.31304348] |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2520s, training loss at epoch 6: 5.6454
# using time 0.2434s, training loss at epoch 7: 5.5731
# using time 0.2434s, training loss at epoch 8: 5.4816
# using time 0.2435s, training loss at epoch 9: 5.3629
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   | hit_ratio |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# |   10  | 0.24211621284484863 | 1.3921685218811035 | 5.227424144744873 | [0.09318742] | [0.08845639] | [0.04834783] |   [0.32]  |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# using time 0.2780s, training loss at epoch 11: 5.0679
# using time 0.2467s, training loss at epoch 12: 4.8980
# using time 0.2371s, training loss at epoch 13: 4.7159
# using time 0.2430s, training loss at epoch 14: 4.5458
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   | hit_ratio |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# |   15  | 0.2412559986114502 | 1.4292118549346924 | 4.360283374786377 | [0.09348862] | [0.08845319] | [0.04852174] |   [0.32]  |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# using time 0.2432s, training loss at epoch 16: 4.2285
# using time 0.2389s, training loss at epoch 17: 4.0959
# using time 0.2807s, training loss at epoch 18: 3.9677
# using time 0.2437s, training loss at epoch 19: 3.8412
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   20  | 0.24205231666564941 | 1.390648365020752 | 3.7830662727355957 | [0.09370029] | [0.08866073] | [0.04878261] | [0.32173913] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2414s, training loss at epoch 21: 3.6895
# using time 0.2406s, training loss at epoch 22: 3.6741
# using time 0.2411s, training loss at epoch 23: 3.5976
# using time 0.2430s, training loss at epoch 24: 3.5026
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   25  | 0.24179792404174805 | 1.3724546432495117 | 3.512045383453369 | [0.09365984] | [0.08877071] | [0.04869565] | [0.32173913] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2397s, training loss at epoch 26: 3.4366
# using time 0.2430s, training loss at epoch 27: 3.4033
# using time 0.2418s, training loss at epoch 28: 3.3480
# using time 0.2430s, training loss at epoch 29: 3.3489
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   30  | 0.24068570137023926 | 1.379126787185669 | 3.2793376445770264 | [0.09407751] | [0.08878333] | [0.04869565] | [0.32173913] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2923s, training loss at epoch 31: 3.2383
# using time 0.2405s, training loss at epoch 32: 3.1997
# using time 0.2419s, training loss at epoch 33: 3.1503
# using time 0.2405s, training loss at epoch 34: 3.1226
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   | hit_ratio |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# |   35  | 0.24329018592834473 | 1.3791024684906006 | 3.104398727416992 | [0.09353781] | [0.08872375] | [0.04852174] |   [0.32]  |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-----------+
# using time 0.2582s, training loss at epoch 36: 3.0618
# using time 0.2413s, training loss at epoch 37: 3.0549
# using time 0.2439s, training loss at epoch 38: 2.9758
# using time 0.2416s, training loss at epoch 39: 3.0093
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |   40  | 0.2404468059539795 | 1.3741304874420166 | 2.9737815856933594 | [0.09560043] | [0.0894928] | [0.04878261] | [0.32173913] |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.2418s, training loss at epoch 41: 2.8896
# using time 0.2446s, training loss at epoch 42: 2.8837
# using time 0.2408s, training loss at epoch 43: 2.8679
# using time 0.2423s, training loss at epoch 44: 2.8315
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   45  | 0.24223875999450684 | 1.3843097686767578 | 2.810438394546509 | [0.09583916] | [0.08969187] | [0.04921739] | [0.32347826] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2751s, training loss at epoch 46: 2.7922
# using time 0.1741s, training loss at epoch 47: 2.7461
# using time 0.1768s, training loss at epoch 48: 2.7138
# using time 0.1713s, training loss at epoch 49: 2.6774
# +-------+--------------------+------------------+------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |  tesing time(s)  |       Loss       |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+------------------+------------------+--------------+-------------+--------------+--------------+
# |   50  | 0.1774299144744873 | 1.45259428024292 | 2.65997052192688 | [0.09662753] | [0.0913306] | [0.04991304] | [0.32521739] |
# +-------+--------------------+------------------+------------------+--------------+-------------+--------------+--------------+
# using time 0.2560s, training loss at epoch 51: 2.6432
# using time 0.2395s, training loss at epoch 52: 2.6245
# using time 0.2421s, training loss at epoch 53: 2.5972
# using time 0.2426s, training loss at epoch 54: 2.5818
# +-------+---------------------+--------------------+-------------------+--------------+--------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+-----------+--------------+
# |   55  | 0.24460411071777344 | 1.4812233448028564 | 2.580855369567871 | [0.09833932] | [0.09171008] |   [0.05]  | [0.33391304] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+-----------+--------------+
# using time 0.2476s, training loss at epoch 56: 2.5457
# using time 0.2419s, training loss at epoch 57: 2.5060
# using time 0.2850s, training loss at epoch 58: 2.4576
# using time 0.2400s, training loss at epoch 59: 2.4677
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   60  | 0.24228119850158691 | 1.4586405754089355 | 2.3894498348236084 | [0.10047909] | [0.09304973] | [0.05034783] | [0.33391304] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2518s, training loss at epoch 61: 2.4344
# using time 0.2415s, training loss at epoch 62: 2.3510
# using time 0.2403s, training loss at epoch 63: 2.3910
# using time 0.2413s, training loss at epoch 64: 2.3711
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio  |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-------------+
# |   65  | 0.24176383018493652 | 1.4242866039276123 | 2.339047908782959 | [0.10215311] | [0.09376535] | [0.05147826] | [0.3373913] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+-------------+
# using time 0.2570s, training loss at epoch 66: 2.3337
# using time 0.2378s, training loss at epoch 67: 2.2784
# using time 0.2402s, training loss at epoch 68: 2.2653
# using time 0.2439s, training loss at epoch 69: 2.2427
# +-------+-------------------+-------------------+------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)  |       Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+-------------------+------------------+--------------+--------------+--------------+--------------+
# |   70  | 0.281538724899292 | 1.430006742477417 | 2.20527720451355 | [0.10303535] | [0.09464719] | [0.05208696] | [0.34434783] |
# +-------+-------------------+-------------------+------------------+--------------+--------------+--------------+--------------+
# using time 0.2481s, training loss at epoch 71: 2.2041
# using time 0.2430s, training loss at epoch 72: 2.1739
# using time 0.2415s, training loss at epoch 73: 2.1813
# using time 0.2426s, training loss at epoch 74: 2.1556
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   75  | 0.24027729034423828 | 1.4464967250823975 | 2.1226887702941895 | [0.10472625] | [0.09551591] | [0.05313043] | [0.35304348] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2602s, training loss at epoch 76: 2.1105
# using time 0.2424s, training loss at epoch 77: 2.1331
# using time 0.2414s, training loss at epoch 78: 2.0626
# using time 0.2439s, training loss at epoch 79: 2.0673
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |   80  | 0.24008417129516602 | 1.4757969379425049 | 2.0236189365386963 | [0.1099074] | [0.09816781] | [0.05408696] | [0.35826087] |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2766s, training loss at epoch 81: 2.0219
# using time 0.2439s, training loss at epoch 82: 2.0046
# using time 0.2817s, training loss at epoch 83: 2.0307
# using time 0.2432s, training loss at epoch 84: 1.9851
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-----------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   | hit_ratio |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-----------+
# |   85  | 0.24308323860168457 | 1.3843135833740234 | 1.9447484016418457 | [0.11072441] | [0.09900815] | [0.05452174] |   [0.36]  |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-----------+
# using time 0.2608s, training loss at epoch 86: 1.9577
# using time 0.2409s, training loss at epoch 87: 1.9472
# using time 0.2436s, training loss at epoch 88: 1.8711
# using time 0.2455s, training loss at epoch 89: 1.8880
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   90  | 0.23903250694274902 | 1.4014899730682373 | 1.8601610660552979 | [0.11244694] | [0.10064347] | [0.05530435] | [0.36521739] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2534s, training loss at epoch 91: 1.8664
# using time 0.2434s, training loss at epoch 92: 1.8083
# using time 0.2379s, training loss at epoch 93: 1.8030
# using time 0.2427s, training loss at epoch 94: 1.8306
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   95  | 0.24402546882629395 | 1.3777403831481934 | 1.746131420135498 | [0.11311196] | [0.10143656] | [0.05608696] | [0.36521739] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2541s, training loss at epoch 96: 1.7816
# using time 0.2783s, training loss at epoch 97: 1.7725
# using time 0.2434s, training loss at epoch 98: 1.7296
# using time 0.2458s, training loss at epoch 99: 1.7568
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  100  | 0.2445824146270752 | 1.3857660293579102 | 1.727109432220459 | [0.11332071] | [0.10206089] | [0.05669565] | [0.36695652] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2518s, training loss at epoch 101: 1.7183
# using time 0.2465s, training loss at epoch 102: 1.6773
# using time 0.2369s, training loss at epoch 103: 1.6522
# using time 0.2426s, training loss at epoch 104: 1.6551
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  105  | 0.24389052391052246 | 1.3790407180786133 | 1.6455947160720825 | [0.11390758] | [0.10208731] | [0.05730435] | [0.36521739] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2405s, training loss at epoch 106: 1.6377
# using time 0.1736s, training loss at epoch 107: 1.6053
# using time 0.1749s, training loss at epoch 108: 1.6161
# using time 0.2187s, training loss at epoch 109: 1.5894
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  110  | 0.1784834861755371 | 1.3819727897644043 | 1.5714975595474243 | [0.11431738] | [0.10352856] | [0.05791304] | [0.36695652] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.1876s, training loss at epoch 111: 1.5706
# using time 0.1814s, training loss at epoch 112: 1.5502
# using time 0.1771s, training loss at epoch 113: 1.5408
# using time 0.1748s, training loss at epoch 114: 1.5167
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# |  115  | 0.17311787605285645 | 1.3835606575012207 | 1.5201704502105713 | [0.11581568] | [0.10404483] |  [0.058]  | [0.37043478] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# using time 0.1928s, training loss at epoch 116: 1.5055
# using time 0.1741s, training loss at epoch 117: 1.4866
# using time 0.1712s, training loss at epoch 118: 1.4928
# using time 0.1720s, training loss at epoch 119: 1.4747
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  120  | 0.17305707931518555 | 1.3802459239959717 | 1.4451626539230347 | [0.11606046] | [0.10518725] | [0.05852174] | [0.37391304] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2366s, training loss at epoch 121: 1.4323
# using time 0.2793s, training loss at epoch 122: 1.4555
# using time 0.2438s, training loss at epoch 123: 1.4058
# using time 0.2431s, training loss at epoch 124: 1.3814
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio  |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# |  125  | 0.24465179443359375 | 1.3723092079162598 | 1.3708641529083252 | [0.11780116] | [0.10633051] | [0.05921739] | [0.3773913] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# using time 0.2654s, training loss at epoch 126: 1.3686
# using time 0.2443s, training loss at epoch 127: 1.3802
# using time 0.2382s, training loss at epoch 128: 1.3980
# using time 0.2415s, training loss at epoch 129: 1.4003
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     | precision |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# |  130  | 0.24302458763122559 | 1.4022367000579834 | 1.3418701887130737 | [0.12130954] | [0.10794481] |   [0.06]  | [0.38086957] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+-----------+--------------+
# using time 0.2572s, training loss at epoch 131: 1.2990
# using time 0.2401s, training loss at epoch 132: 1.3051
# using time 0.2419s, training loss at epoch 133: 1.3119
# using time 0.2476s, training loss at epoch 134: 1.2784
# +-------+---------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |  tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# |  135  | 0.23612070083618164 | 1.38614821434021 | 1.3005846738815308 | [0.12057569] | [0.10844775] | [0.06017391] | [0.38434783] |
# +-------+---------------------+------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.3047s, training loss at epoch 136: 1.2791
# using time 0.2408s, training loss at epoch 137: 1.2781
# using time 0.2435s, training loss at epoch 138: 1.2528
# using time 0.2401s, training loss at epoch 139: 1.2521
# +-------+---------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# |  140  | 0.24179983139038086 | 1.3946146965026855 | 1.210737705230713 | [0.12005373] | [0.1089983] | [0.06043478] | [0.38434783] |
# +-------+---------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# using time 0.2520s, training loss at epoch 141: 1.2631
# using time 0.2451s, training loss at epoch 142: 1.2355
# using time 0.2404s, training loss at epoch 143: 1.1753
# using time 0.2435s, training loss at epoch 144: 1.2101
# +-------+--------------------+-------------------+------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |       Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+------------------+--------------+--------------+--------------+--------------+
# |  145  | 0.2407374382019043 | 1.383209228515625 | 1.23310387134552 | [0.11978287] | [0.10904346] | [0.06034783] | [0.38608696] |
# +-------+--------------------+-------------------+------------------+--------------+--------------+--------------+--------------+
# using time 0.2520s, training loss at epoch 146: 1.1965
# using time 0.2416s, training loss at epoch 147: 1.1730
# using time 0.2833s, training loss at epoch 148: 1.1813
# using time 0.2416s, training loss at epoch 149: 1.1704
# +-------+---------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# |  150  | 0.24079132080078125 | 1.402925968170166 | 1.1527090072631836 | [0.11868586] | [0.10895337] | [0.0606087] | [0.38608696] |
# +-------+---------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# using time 0.2337s, training loss at epoch 151: 1.1535
# using time 0.2359s, training loss at epoch 152: 1.1332
# using time 0.2420s, training loss at epoch 153: 1.1424
# using time 0.2424s, training loss at epoch 154: 1.1228
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  155  | 0.2418680191040039 | 1.3990657329559326 | 1.1383144855499268 | [0.11888719] | [0.10883842] | [0.06008696] | [0.38434783] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2326s, training loss at epoch 156: 1.1023
# using time 0.2402s, training loss at epoch 157: 1.1005
# using time 0.2426s, training loss at epoch 158: 1.0790
# using time 0.2421s, training loss at epoch 159: 1.0862
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  160  | 0.24103283882141113 | 1.3950068950653076 | 1.0747967958450317 | [0.12167739] | [0.10961999] | [0.06086957] | [0.38956522] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2999s, training loss at epoch 161: 1.0767
# using time 0.2401s, training loss at epoch 162: 1.0481
# using time 0.2420s, training loss at epoch 163: 1.0636
# using time 0.2442s, training loss at epoch 164: 1.0097
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  165  | 0.24268674850463867 | 1.3856184482574463 | 1.0373190641403198 | [0.12143075] | [0.10954896] | [0.06113043] | [0.38956522] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2522s, training loss at epoch 166: 1.0287
# using time 0.2365s, training loss at epoch 167: 1.0396
# using time 0.2422s, training loss at epoch 168: 0.9764
# using time 0.2436s, training loss at epoch 169: 0.9907
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  170  | 0.24309492111206055 | 1.3857386112213135 | 0.998726487159729 | [0.11917351] | [0.10918383] | [0.06095652] | [0.38608696] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2483s, training loss at epoch 171: 1.0043
# using time 0.2388s, training loss at epoch 172: 1.0252
# using time 0.2414s, training loss at epoch 173: 0.9829
# using time 0.2456s, training loss at epoch 174: 0.9757
# +-------+---------------------+-------------------+-------------------+--------------+--------------+-------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+-------------+--------------+
# |  175  | 0.24266529083251953 | 1.380239725112915 | 0.975570797920227 | [0.12054298] | [0.10992701] | [0.0613913] | [0.39130435] |
# +-------+---------------------+-------------------+-------------------+--------------+--------------+-------------+--------------+
# using time 0.2885s, training loss at epoch 176: 0.9760
# using time 0.2386s, training loss at epoch 177: 0.9646
# using time 0.2449s, training loss at epoch 178: 0.9401
# using time 0.2402s, training loss at epoch 179: 0.9578
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  180  | 0.24075102806091309 | 1.3802850246429443 | 0.9401843547821045 | [0.1203802] | [0.10994235] | [0.06113043] | [0.39130435] |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2804s, training loss at epoch 181: 0.9320
# using time 0.2374s, training loss at epoch 182: 0.9347
# using time 0.2419s, training loss at epoch 183: 0.9102
# using time 0.2413s, training loss at epoch 184: 0.8949
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  185  | 0.24573707580566406 | 1.3851878643035889 | 0.8881978988647461 | [0.12197392] | [0.11069472] | [0.06130435] | [0.39478261] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2393s, training loss at epoch 186: 0.8948
# using time 0.2792s, training loss at epoch 187: 0.8984
# using time 0.2458s, training loss at epoch 188: 0.8900
# using time 0.2373s, training loss at epoch 189: 0.9035
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  190  | 0.24334383010864258 | 1.4021878242492676 | 0.8937177658081055 | [0.12181117] | [0.11099491] | [0.06121739] | [0.39826087] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2510s, training loss at epoch 191: 0.8930
# using time 0.2371s, training loss at epoch 192: 0.8724
# using time 0.2589s, training loss at epoch 193: 0.8869
# using time 0.2387s, training loss at epoch 194: 0.8755
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+-----------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   | hit_ratio |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+-----------+
# |  195  | 0.2388145923614502 | 1.3962798118591309 | 0.8639583587646484 | [0.12388533] | [0.11201844] | [0.06130435] |   [0.4]   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+-----------+
# using time 0.2485s, training loss at epoch 196: 0.8423
# using time 0.2446s, training loss at epoch 197: 0.8432
# using time 0.2373s, training loss at epoch 198: 0.8247
# using time 0.2806s, training loss at epoch 199: 0.8264
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  200  | 0.23378992080688477 | 1.3838880062103271 | 0.8254035711288452 | [0.1232404] | [0.11152897] | [0.06095652] | [0.39826087] |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2611s, training loss at epoch 201: 0.8442
# using time 0.2427s, training loss at epoch 202: 0.8114
# using time 0.2452s, training loss at epoch 203: 0.8195
# using time 0.2409s, training loss at epoch 204: 0.8048
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  205  | 0.24341726303100586 | 1.3715910911560059 | 0.8078522682189941 | [0.12222876] | [0.11206986] | [0.06121739] | [0.40173913] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2475s, training loss at epoch 206: 0.7983
# using time 0.2398s, training loss at epoch 207: 0.7904
# using time 0.2435s, training loss at epoch 208: 0.8069
# using time 0.2411s, training loss at epoch 209: 0.8071
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  210  | 0.24292206764221191 | 1.3880529403686523 | 0.7893627882003784 | [0.12266706] | [0.11297535] | [0.06130435] | [0.40173913] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2517s, training loss at epoch 211: 0.7605
# using time 0.2798s, training loss at epoch 212: 0.7755
# using time 0.2426s, training loss at epoch 213: 0.7770
# using time 0.2453s, training loss at epoch 214: 0.7853
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  215  | 0.23780393600463867 | 1.3753125667572021 | 0.7672508955001831 | [0.12323517] | [0.11361513] | [0.06130435] | [0.40173913] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2586s, training loss at epoch 216: 0.7723
# using time 0.2422s, training loss at epoch 217: 0.7429
# using time 0.2444s, training loss at epoch 218: 0.7490
# using time 0.2409s, training loss at epoch 219: 0.7298
# +-------+---------------------+--------------------+--------------------+-------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+-------------+-------------+--------------+--------------+
# |  220  | 0.24196314811706543 | 1.3700284957885742 | 0.7319886088371277 | [0.1239859] | [0.1138254] | [0.06165217] | [0.40347826] |
# +-------+---------------------+--------------------+--------------------+-------------+-------------+--------------+--------------+
# using time 0.2709s, training loss at epoch 221: 0.7366
# using time 0.2406s, training loss at epoch 222: 0.7158
# using time 0.2420s, training loss at epoch 223: 0.7243
# using time 0.2417s, training loss at epoch 224: 0.7050
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  225  | 0.24323654174804688 | 1.3867475986480713 | 0.7113942503929138 | [0.12412559] | [0.11412457] | [0.06173913] | [0.40347826] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2988s, training loss at epoch 226: 0.7258
# using time 0.2371s, training loss at epoch 227: 0.7000
# using time 0.2417s, training loss at epoch 228: 0.6872
# using time 0.2429s, training loss at epoch 229: 0.7039
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  230  | 0.24268794059753418 | 1.3968801498413086 | 0.7078496217727661 | [0.12404659] | [0.11411415] | [0.06173913] | [0.40521739] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2731s, training loss at epoch 231: 0.6822
# using time 0.2410s, training loss at epoch 232: 0.6992
# using time 0.2417s, training loss at epoch 233: 0.6610
# using time 0.2630s, training loss at epoch 234: 0.6585
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  235  | 0.24286127090454102 | 1.3820843696594238 | 0.6700296401977539 | [0.1250164] | [0.11480223] | [0.06182609] | [0.40695652] |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2338s, training loss at epoch 236: 0.6851
# using time 0.2353s, training loss at epoch 237: 0.6707
# using time 0.2815s, training loss at epoch 238: 0.6821
# using time 0.2440s, training loss at epoch 239: 0.6971
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  240  | 0.2420029640197754 | 1.3812689781188965 | 0.6659020781517029 | [0.1249445] | [0.11513294] | [0.06182609] | [0.40521739] |
# +-------+--------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2456s, training loss at epoch 241: 0.6439
# using time 0.2446s, training loss at epoch 242: 0.6468
# using time 0.2425s, training loss at epoch 243: 0.6575
# using time 0.2446s, training loss at epoch 244: 0.6545
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  245  | 0.24157190322875977 | 1.3697524070739746 | 0.6440037488937378 | [0.12529553] | [0.11488307] | [0.06226087] | [0.40521739] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2520s, training loss at epoch 246: 0.6755
# using time 0.2373s, training loss at epoch 247: 0.6516
# using time 0.2414s, training loss at epoch 248: 0.6401
# using time 0.2410s, training loss at epoch 249: 0.6108
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  250  | 0.2846388816833496 | 1.3811421394348145 | 0.6437880992889404 | [0.12506121] | [0.11512639] | [0.06208696] | [0.40695652] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2584s, training loss at epoch 251: 0.6342
# using time 0.2434s, training loss at epoch 252: 0.5884
# using time 0.2402s, training loss at epoch 253: 0.6111
# using time 0.2442s, training loss at epoch 254: 0.6205
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# |  255  | 0.24259543418884277 | 1.3913273811340332 | 0.6318953037261963 | [0.1246504] | [0.11515943] | [0.06173913] | [0.40521739] |
# +-------+---------------------+--------------------+--------------------+-------------+--------------+--------------+--------------+
# using time 0.2569s, training loss at epoch 256: 0.6141
# using time 0.2419s, training loss at epoch 257: 0.5962
# using time 0.2444s, training loss at epoch 258: 0.6151
# using time 0.2481s, training loss at epoch 259: 0.6452
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  260  | 0.24686908721923828 | 1.3830649852752686 | 0.609108567237854 | [0.12453793] | [0.11487643] | [0.06156522] | [0.40347826] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2630s, training loss at epoch 261: 0.5780
# using time 0.2413s, training loss at epoch 262: 0.5980
# using time 0.2844s, training loss at epoch 263: 0.5688
# using time 0.2402s, training loss at epoch 264: 0.5834
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  265  | 0.24597883224487305 | 1.4038994312286377 | 0.579319953918457 | [0.12651133] | [0.11547068] | [0.06165217] | [0.40521739] |
# +-------+---------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2573s, training loss at epoch 266: 0.5992
# using time 0.2394s, training loss at epoch 267: 0.5640
# using time 0.2353s, training loss at epoch 268: 0.5753
# using time 0.2465s, training loss at epoch 269: 0.5565
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# ...
# using time 0.2772s, training loss at epoch 277: 0.5461
# using time 0.2374s, training loss at epoch 278: 0.5677
# using time 0.2424s, training loss at epoch 279: 0.5397
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |  280  | 0.23427176475524902 | 1.3790810108184814 | 0.5414449572563171 | [0.12755525] | [0.1166975] | [0.06278261] | [0.40869565] |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.2498s, training loss at epoch 281: 0.5279
# using time 0.2402s, training loss at epoch 282: 0.5556
# using time 0.2439s, training loss at epoch 283: 0.5706
# using time 0.2426s, training loss at epoch 284: 0.5412
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  285  | 0.23968935012817383 | 1.3735065460205078 | 0.5215097665786743 | [0.12785532] | [0.11712446] | [0.06252174] | [0.40869565] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2561s, training loss at epoch 286: 0.5356
# using time 0.2446s, training loss at epoch 287: 0.5292
# using time 0.2373s, training loss at epoch 288: 0.5340
# using time 0.2829s, training loss at epoch 289: 0.5378
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |  290  | 0.24254202842712402 | 1.3571579456329346 | 0.5164376497268677 | [0.12799462] | [0.1176442] | [0.06269565] | [0.40869565] |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.2569s, training loss at epoch 291: 0.5514
# using time 0.2408s, training loss at epoch 292: 0.5399
# using time 0.2474s, training loss at epoch 293: 0.5462
# using time 0.2393s, training loss at epoch 294: 0.5380
# +-------+-------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |  295  | 0.237687349319458 | 1.3807532787322998 | 0.548681378364563 | [0.12869027] | [0.11822192] | [0.06286957] | [0.40869565] |
# +-------+-------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 0.2411s, training loss at epoch 296: 0.5324
# using time 0.2430s, training loss at epoch 297: 0.5397
# using time 0.2424s, training loss at epoch 298: 0.5717
# using time 0.2424s, training loss at epoch 299: 0.5748
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  300  | 0.24224042892456055 | 1.3794519901275635 | 0.6791502237319946 | [0.12998719] | [0.11851298] | [0.06330435] | [0.40869565] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2458s, training loss at epoch 301: 0.6396
# using time 0.2788s, training loss at epoch 302: 0.5954
# using time 0.2464s, training loss at epoch 303: 0.5630
# using time 0.2397s, training loss at epoch 304: 0.5261
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |         Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# |  305  | 0.24242639541625977 | 1.3928117752075195 | 0.48657822608947754 | [0.12793145] | [0.11787889] | [0.06304348] | [0.40347826] |
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# using time 0.2571s, training loss at epoch 306: 0.4593
# using time 0.2418s, training loss at epoch 307: 0.4358
# using time 0.2440s, training loss at epoch 308: 0.4074
# using time 0.2439s, training loss at epoch 309: 0.3852
# +-------+---------------------+--------------------+--------------------+--------------+-------------+-----------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    | precision |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+-----------+--------------+
# |  310  | 0.24131298065185547 | 1.3765950202941895 | 0.3562951683998108 | [0.13141155] | [0.1202207] |  [0.064]  | [0.40695652] |
# +-------+---------------------+--------------------+--------------------+--------------+-------------+-----------+--------------+
# using time 0.2600s, training loss at epoch 311: 0.3471
# using time 0.2410s, training loss at epoch 312: 0.3323
# using time 0.2424s, training loss at epoch 313: 0.3169
# using time 0.2433s, training loss at epoch 314: 0.3151
# +-------+---------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# |  315  | 0.24091196060180664 | 1.391176700592041 | 0.3024722635746002 | [0.13349956] | [0.1209507] | [0.06426087] | [0.40347826] |
# +-------+---------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 0.2935s, training loss at epoch 316: 0.2921
# using time 0.2434s, training loss at epoch 317: 0.2822
# using time 0.2419s, training loss at epoch 318: 0.2712
# using time 0.2422s, training loss at epoch 319: 0.2622
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  320  | 0.24045586585998535 | 1.4039103984832764 | 0.2794196903705597 | [0.13248486] | [0.11947444] | [0.06391304] | [0.40173913] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2473s, training loss at epoch 321: 0.2594
# using time 0.2441s, training loss at epoch 322: 0.2513
# using time 0.2449s, training loss at epoch 323: 0.2438
# using time 0.2435s, training loss at epoch 324: 0.2444
# +-------+--------------------+--------------------+---------------------+--------------+-------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |         Loss        |    recall    |     ndcg    |  precision  |  hit_ratio   |
# +-------+--------------------+--------------------+---------------------+--------------+-------------+-------------+--------------+
# |  325  | 0.2407369613647461 | 1.3862714767456055 | 0.23964649438858032 | [0.13037077] | [0.1188401] | [0.0633913] | [0.39826087] |
# +-------+--------------------+--------------------+---------------------+--------------+-------------+-------------+--------------+
# using time 0.2548s, training loss at epoch 326: 0.2381
# using time 0.2404s, training loss at epoch 327: 0.2325
# using time 0.2822s, training loss at epoch 328: 0.2217
# using time 0.2401s, training loss at epoch 329: 0.2196
# +-------+---------------------+--------------------+---------------------+-------------+--------------+-------------+-----------+
# | Epoch |   training time(s)  |   tesing time(s)   |         Loss        |    recall   |     ndcg     |  precision  | hit_ratio |
# +-------+---------------------+--------------------+---------------------+-------------+--------------+-------------+-----------+
# |  330  | 0.24255800247192383 | 1.4609317779541016 | 0.23026365041732788 | [0.1306964] | [0.11930579] | [0.0633913] |   [0.4]   |
# +-------+---------------------+--------------------+---------------------+-------------+--------------+-------------+-----------+
# using time 0.2491s, training loss at epoch 331: 0.2270
# using time 0.2411s, training loss at epoch 332: 0.2225
# using time 0.2438s, training loss at epoch 333: 0.2090
# using time 0.2409s, training loss at epoch 334: 0.2178
# +-------+------------------+--------------------+---------------------+--------------+--------------+-------------+--------------+
# | Epoch | training time(s) |   tesing time(s)   |         Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+------------------+--------------------+---------------------+--------------+--------------+-------------+--------------+
# |  335  | 0.23846435546875 | 1.5145084857940674 | 0.21636807918548584 | [0.13057108] | [0.11883514] | [0.0633913] | [0.39826087] |
# +-------+------------------+--------------------+---------------------+--------------+--------------+-------------+--------------+
# using time 0.2647s, training loss at epoch 336: 0.1990
# using time 0.2504s, training loss at epoch 337: 0.2030
# using time 0.2440s, training loss at epoch 338: 0.2012
# using time 0.2412s, training loss at epoch 339: 0.2207
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |         Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# |  340  | 0.29026293754577637 | 1.5074515342712402 | 0.20147378742694855 | [0.12892055] | [0.11842543] | [0.06356522] | [0.39826087] |
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# using time 0.2621s, training loss at epoch 341: 0.1863
# using time 0.2422s, training loss at epoch 342: 0.1872
# using time 0.2411s, training loss at epoch 343: 0.1982
# using time 0.2467s, training loss at epoch 344: 0.1867
# +-------+--------------------+--------------------+---------------------+--------------+--------------+--------------+-----------+
# | Epoch |  training time(s)  |   tesing time(s)   |         Loss        |    recall    |     ndcg     |  precision   | hit_ratio |
# +-------+--------------------+--------------------+---------------------+--------------+--------------+--------------+-----------+
# |  345  | 0.2539842128753662 | 1.4626522064208984 | 0.18454313278198242 | [0.12991752] | [0.11872316] | [0.06365217] |   [0.4]   |
# +-------+--------------------+--------------------+---------------------+--------------+--------------+--------------+-----------+
# using time 0.2503s, training loss at epoch 346: 0.1962
# using time 0.2407s, training loss at epoch 347: 0.1836
# using time 0.2443s, training loss at epoch 348: 0.1889
# using time 0.2356s, training loss at epoch 349: 0.2025
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  350  | 0.24062585830688477 | 1.4700477123260498 | 0.1917279213666916 | [0.12916493] | [0.11838515] | [0.06356522] | [0.39478261] |
# +-------+---------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2772s, training loss at epoch 351: 0.1834
# using time 0.2329s, training loss at epoch 352: 0.1795
# using time 0.2956s, training loss at epoch 353: 0.1807
# using time 0.2376s, training loss at epoch 354: 0.1630
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |  355  | 0.2411799430847168 | 1.4717459678649902 | 0.1624891459941864 | [0.12912406] | [0.11819854] | [0.06347826] | [0.39478261] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 0.2631s, training loss at epoch 356: 0.1804
# using time 0.2439s, training loss at epoch 357: 0.1641
# using time 0.2403s, training loss at epoch 358: 0.1570
# using time 0.2425s, training loss at epoch 359: 0.1577
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |         Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# |  360  | 0.24278974533081055 | 1.4793732166290283 | 0.16265884041786194 | [0.12806669] | [0.11798505] | [0.06321739] | [0.39652174] |
# +-------+---------------------+--------------------+---------------------+--------------+--------------+--------------+--------------+
# using time 0.2691s, training loss at epoch 361: 0.1583
# using time 0.2413s, training loss at epoch 362: 0.1484
# using time 0.2431s, training loss at epoch 363: 0.1546
# using time 0.2445s, training loss at epoch 364: 0.1644
# +-------+---------------------+--------------------+---------------------+--------------+-------------+--------------+--------------+
# | Epoch |   training time(s)  |   tesing time(s)   |         Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+---------------------+--------------------+---------------------+--------------+-------------+--------------+--------------+
# |  365  | 0.24038386344909668 | 1.4943244457244873 | 0.15988929569721222 | [0.12800872] | [0.1178645] | [0.06321739] | [0.39652174] |
# +-------+---------------------+--------------------+---------------------+--------------+-------------+--------------+--------------+
# Early stopping is trigger at step: 10 log:0.1280087210236062
# early stopping at 365, recall@20:0.1335
