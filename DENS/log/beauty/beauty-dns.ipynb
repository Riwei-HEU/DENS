# %%
# %load main.py
import os
import random

import torch
import numpy as np

from time import time
from tqdm import tqdm
from copy import deepcopy
import logging
from prettytable import PrettyTable

from utils.parser import parse_args
from utils.data_loader import load_data
from utils.evaluate import test
from utils.helper import early_stopping

n_users = 0
n_items = 0


def get_feed_dict(train_entity_pairs, train_pos_set, start, end, n_negs=1):

    def sampling(user_item, train_set, n):
        neg_items = []
        for user, _ in user_item.cpu().numpy():
            user = int(user)
            negitems = []
            for i in range(n):  # sample n times
                while True:
                    negitem = random.choice(range(n_items))
                    if negitem not in train_set[user]:
                        break
                negitems.append(negitem)
            neg_items.append(negitems)
        return neg_items

    feed_dict = {}
    entity_pairs = train_entity_pairs[start:end]
    feed_dict['users'] = entity_pairs[:, 0]
    feed_dict['pos_items'] = entity_pairs[:, 1]
    feed_dict['neg_items'] = torch.LongTensor(sampling(entity_pairs,
                                                       train_pos_set,
                                                       n_negs*K)).to(device)
    return feed_dict


if __name__ == '__main__':
    """fix the random seed"""
    seed = 2020
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    """read args"""
    global args, device
    args = parse_args()
    os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu_id)
    device = torch.device("cuda:0") if args.cuda else torch.device("cpu")

    """build dataset"""
    train_cf, user_dict, n_params, norm_mat = load_data(args)
    train_cf_size = len(train_cf)
    train_cf = torch.LongTensor(np.array([[cf[0], cf[1]] for cf in train_cf], np.int32))

    n_users = n_params['n_users']
    n_items = n_params['n_items']
    n_negs = args.n_negs
    K = args.K

    """define model"""
    from modules.LightGCN import LightGCN
    if args.gnn == 'lightgcn':
        model = LightGCN(n_params, args, norm_mat).to(device)

    """define optimizer"""
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    cur_best_pre_0 = 0
    stopping_step = 0
    should_stop = False

    print("start training ...")
    for epoch in range(args.epoch):
        # shuffle training data
        train_cf_ = train_cf
        index = np.arange(len(train_cf_))
        np.random.shuffle(index)
        train_cf_ = train_cf_[index].to(device)

        """training"""
        model.train()
        loss, s = 0, 0
        hits = 0
        train_s_t = time()
        while s + args.batch_size <= len(train_cf):
            batch = get_feed_dict(train_cf_,
                                  user_dict['train_user_set'],
                                  s, s + args.batch_size,
                                  n_negs)

            batch_loss, _, _ = model(epoch, batch)

            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            loss += batch_loss
            s += args.batch_size

        train_e_t = time()

        if epoch % 5 == 0:
            """testing"""

            train_res = PrettyTable()
            train_res.field_names = ["Epoch", "training time(s)", "tesing time(s)", "Loss", "recall", "ndcg", "precision", "hit_ratio"]

            model.eval()
            test_s_t = time()
            test_ret = test(model, user_dict, n_params, mode='test')
            test_e_t = time()
            train_res.add_row(
                [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), test_ret['recall'], test_ret['ndcg'],
                 test_ret['precision'], test_ret['hit_ratio']])

            if user_dict['valid_user_set'] is None:
                valid_ret = test_ret
            else:
                test_s_t = time()
                valid_ret = test(model, user_dict, n_params, mode='valid')
                test_e_t = time()
                train_res.add_row(
                    [epoch, train_e_t - train_s_t, test_e_t - test_s_t, loss.item(), valid_ret['recall'], valid_ret['ndcg'],
                     valid_ret['precision'], valid_ret['hit_ratio']])
            print(train_res)

            # *********************************************************
            # early stopping when cur_best_pre_0 is decreasing for 10 successive steps.
            cur_best_pre_0, stopping_step, should_stop = early_stopping(valid_ret['recall'][0], cur_best_pre_0,
                                                                        stopping_step, expected_order='acc',
                                                                        flag_step=10)
            if should_stop:
                break

            """save weight"""
            if valid_ret['recall'][0] == cur_best_pre_0 and args.save:
                torch.save(model.state_dict(), args.out_dir + 'model_' + '.ckpt')
        else:
            # logging.info('training loss at epoch %d: %f' % (epoch, loss.item()))
            print('using time %.4fs, training loss at epoch %d: %.4f' % (train_e_t - train_s_t, epoch, loss.item()))

    print('early stopping at %d, recall@20:%.4f' % (epoch, cur_best_pre_0))
# Out:
# reading train and test user-item set ...
# building the adj mat ...
# {'n_users': 7670, 'n_items': 10887}
# loading over ...
# start training ...
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# |   0   | 1.2603464126586914 | 3.253218412399292 | 21.44581413269043 | [0.01625443] | [0.00912016] | [0.00248425] | [0.03736879] |
# +-------+--------------------+-------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.2350s, training loss at epoch 1: 20.9993
# using time 1.2180s, training loss at epoch 2: 19.8942
# using time 1.2174s, training loss at epoch 3: 18.6044
# using time 1.2151s, training loss at epoch 4: 17.6188
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   5   | 1.1651735305786133 | 3.306614398956299 | 16.924373626708984 | [0.03041206] | [0.01680245] | [0.00444367] | [0.07025892] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 1.2030s, training loss at epoch 6: 16.4126
# using time 1.2741s, training loss at epoch 7: 15.9279
# using time 1.1752s, training loss at epoch 8: 15.5689
# using time 1.2164s, training loss at epoch 9: 15.0711
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# |   10  | 1.1601440906524658 | 3.355341911315918 | 14.701441764831543 | [0.03625651] | [0.01974593] | [0.00515045] | [0.07977607] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 1.1876s, training loss at epoch 11: 14.2328
# using time 1.2121s, training loss at epoch 12: 13.8294
# using time 1.2069s, training loss at epoch 13: 13.3369
# using time 1.2436s, training loss at epoch 14: 12.9502
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# |   15  | 1.248375654220581 | 3.8327581882476807 | 12.494080543518066 | [0.03816881] | [0.02101185] | [0.00544437] | [0.08257523] |
# +-------+-------------------+--------------------+--------------------+--------------+--------------+--------------+--------------+
# using time 1.2914s, training loss at epoch 16: 12.0707
# using time 1.1710s, training loss at epoch 17: 11.6209
# using time 1.2531s, training loss at epoch 18: 11.2285
# using time 1.2105s, training loss at epoch 19: 10.9029
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio  |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# |   20  | 1.2036340236663818 | 3.5151565074920654 | 10.530121803283691 | [0.03963352] | [0.02167274] | [0.00556333] | [0.0846746] |
# +-------+--------------------+--------------------+--------------------+--------------+--------------+--------------+-------------+
# using time 1.3072s, training loss at epoch 21: 10.1127
# using time 1.1874s, training loss at epoch 22: 9.7697
# using time 1.2003s, training loss at epoch 23: 9.4714
# using time 1.2106s, training loss at epoch 24: 9.1098
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# |   25  | 1.2006661891937256 | 3.2966389656066895 | 8.827154159545898 | [0.0398596] | [0.02191884] | [0.00558432] | [0.08495451] |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# using time 1.5188s, training loss at epoch 26: 8.5399
# using time 1.2338s, training loss at epoch 27: 8.3073
# using time 1.2320s, training loss at epoch 28: 8.0006
# using time 1.1951s, training loss at epoch 29: 7.7690
# +-------+--------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |       Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# |   30  | 1.2083117961883545 | 3.1013875007629395 | 7.46827507019043 | [0.04087768] | [0.02228137] | [0.00574528] | [0.08635409] |
# +-------+--------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# using time 1.2101s, training loss at epoch 31: 7.3326
# using time 1.2016s, training loss at epoch 32: 7.0776
# using time 1.1937s, training loss at epoch 33: 6.8703
# using time 1.1701s, training loss at epoch 34: 6.6257
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# |   35  | 1.2365162372589111 | 2.9585554599761963 | 6.474544525146484 | [0.04171821] | [0.0226365] | [0.00583625] | [0.08719384] |
# +-------+--------------------+--------------------+-------------------+--------------+-------------+--------------+--------------+
# using time 1.3207s, training loss at epoch 36: 6.3517
# using time 1.4123s, training loss at epoch 37: 6.1582
# using time 1.2348s, training loss at epoch 38: 6.0299
# using time 1.2259s, training loss at epoch 39: 5.8093
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   40  | 1.2008609771728516 | 2.9626927375793457 | 5.681119441986084 | [0.04182222] | [0.02261953] | [0.00586424] | [0.08705388] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.2081s, training loss at epoch 41: 5.5923
# using time 1.3136s, training loss at epoch 42: 5.4166
# using time 1.2250s, training loss at epoch 43: 5.2676
# using time 1.2071s, training loss at epoch 44: 5.1936
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall   |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# |   45  | 1.3006505966186523 | 2.9343883991241455 | 5.073662757873535 | [0.0416489] | [0.02250871] | [0.00585724] | [0.08691393] |
# +-------+--------------------+--------------------+-------------------+-------------+--------------+--------------+--------------+
# using time 1.1904s, training loss at epoch 46: 4.9931
# using time 1.1996s, training loss at epoch 47: 4.8056
# using time 1.2586s, training loss at epoch 48: 4.7390
# using time 1.2323s, training loss at epoch 49: 4.6413
# +-------+--------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# |   50  | 1.2228376865386963 | 2.891896963119507 | 4.6254801750183105 | [0.04147292] | [0.0226159] | [0.00584325] | [0.08593422] |
# +-------+--------------------+-------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 1.2608s, training loss at epoch 51: 4.4835
# using time 1.3004s, training loss at epoch 52: 4.3424
# using time 1.3189s, training loss at epoch 53: 4.2489
# using time 1.2305s, training loss at epoch 54: 4.1904
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   55  | 1.2107329368591309 | 2.9903950691223145 | 4.059138774871826 | [0.04154981] | [0.02263119] | [0.00587824] | [0.08607418] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.2478s, training loss at epoch 56: 4.0011
# using time 1.1684s, training loss at epoch 57: 3.9728
# using time 1.3819s, training loss at epoch 58: 3.8307
# using time 1.2570s, training loss at epoch 59: 3.7778
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# |   60  | 1.2258877754211426 | 2.9147086143493652 | 3.719743490219116 | [0.04177433] | [0.02266251] | [0.00592022] | [0.08677397] |
# +-------+--------------------+--------------------+-------------------+--------------+--------------+--------------+--------------+
# using time 1.2339s, training loss at epoch 61: 3.6591
# using time 1.1608s, training loss at epoch 62: 3.5853
# using time 1.2328s, training loss at epoch 63: 3.4258
# using time 1.3898s, training loss at epoch 64: 3.3871
# +-------+--------------------+------------------+------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s)  |  tesing time(s)  |       Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+--------------------+------------------+------------------+--------------+--------------+--------------+--------------+
# |   65  | 1.1919822692871094 | 3.01350998878479 | 3.36124849319458 | [0.04145359] | [0.02261309] | [0.00586424] | [0.08579426] |
# +-------+--------------------+------------------+------------------+--------------+--------------+--------------+--------------+
# using time 1.3464s, training loss at epoch 66: 3.3136
# using time 1.2197s, training loss at epoch 67: 3.2635
# using time 1.1783s, training loss at epoch 68: 3.1796
# using time 1.2003s, training loss at epoch 69: 3.1214
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+-------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision   |  hit_ratio  |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+-------------+
# |   70  | 1.2541568279266357 | 2.981611728668213 | 3.1356630325317383 | [0.04099445] | [0.02230073] | [0.00579426] | [0.0846746] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+--------------+-------------+
# using time 1.2397s, training loss at epoch 71: 3.0729
# using time 1.2287s, training loss at epoch 72: 3.0439
# using time 1.1706s, training loss at epoch 73: 2.9217
# using time 1.1979s, training loss at epoch 74: 2.8751
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)   |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# |   75  | 1.1596052646636963 | 2.8974695205688477 | 2.8197853565216064 | [0.04110663] | [0.0223761] | [0.00580826] | [0.08523443] |
# +-------+--------------------+--------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 1.1181s, training loss at epoch 76: 2.7787
# using time 1.1338s, training loss at epoch 77: 2.8111
# using time 1.1087s, training loss at epoch 78: 2.7034
# using time 1.1033s, training loss at epoch 79: 2.6809
# +-------+--------------------+------------------+--------------------+--------------+-------------+--------------+--------------+
# | Epoch |  training time(s)  |  tesing time(s)  |        Loss        |    recall    |     ndcg    |  precision   |  hit_ratio   |
# +-------+--------------------+------------------+--------------------+--------------+-------------+--------------+--------------+
# |   80  | 1.1159634590148926 | 2.77988338470459 | 2.5980236530303955 | [0.04094153] | [0.0221454] | [0.00578027] | [0.08523443] |
# +-------+--------------------+------------------+--------------------+--------------+-------------+--------------+--------------+
# using time 1.1282s, training loss at epoch 81: 2.6292
# using time 1.1071s, training loss at epoch 82: 2.5773
# using time 1.1669s, training loss at epoch 83: 2.5035
# using time 1.0902s, training loss at epoch 84: 2.4443
# +-------+-------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# | Epoch |  training time(s) |   tesing time(s)   |       Loss       |    recall    |     ndcg     |  precision   |  hit_ratio   |
# +-------+-------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# |   85  | 1.108391284942627 | 2.8349874019622803 | 2.43684720993042 | [0.04136339] | [0.02212034] | [0.00575927] | [0.08495451] |
# +-------+-------------------+--------------------+------------------+--------------+--------------+--------------+--------------+
# using time 1.1148s, training loss at epoch 86: 2.4360
# using time 1.1133s, training loss at epoch 87: 2.3963
# using time 1.1258s, training loss at epoch 88: 2.3504
# using time 1.0971s, training loss at epoch 89: 2.2692
# +-------+--------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# | Epoch |  training time(s)  |   tesing time(s)  |        Loss        |    recall    |     ndcg     |  precision  |  hit_ratio   |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# |   90  | 1.1157917976379395 | 2.870081663131714 | 2.2115917205810547 | [0.04082325] | [0.02196735] | [0.0056543] | [0.08341498] |
# +-------+--------------------+-------------------+--------------------+--------------+--------------+-------------+--------------+
# Early stopping is trigger at step: 10 log:0.04082325218209333
# early stopping at 90, recall@20:0.0418
